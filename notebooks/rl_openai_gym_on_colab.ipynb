# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/DQN/blob/main/rl_openai_gym_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OpenAI Gym on Google Colab

# %% [markdown]
# 必要なライブラリのインストール

# %%
# !apt -qq update
# !apt -qq -y install libnvtoolsext1
# !apt -qq -y install xvfb freeglut3-dev ffmpeg
# !pip -q install gym
# !pip -q install pyglet
# !pip -q install pyopengl
# !pip -q install pyvirtualdisplay
# Out:
# 58 packages can be upgraded. Run 'apt list --upgradable' to see them.
# The following NEW packages will be installed:
#   libnvtoolsext1
# 0 upgraded, 1 newly installed, 0 to remove and 58 not upgraded.
# Need to get 31.3 kB of archives.
# After this operation, 147 kB of additional disk space will be used.
# Selecting previously unselected package libnvtoolsext1:amd64.
# (Reading database ... 155047 files and directories currently installed.)
# Preparing to unpack .../libnvtoolsext1_9.1.85-3ubuntu1_amd64.deb ...
# Unpacking libnvtoolsext1:amd64 (9.1.85-3ubuntu1) ...
# Setting up libnvtoolsext1:amd64 (9.1.85-3ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# freeglut3-dev is already the newest version (2.8.1-3).
# freeglut3-dev set to manually installed.
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 58 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,270 kB of additional disk space will be used.
# Selecting previously unselected package xvfb.
# (Reading database ... 155053 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.9_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.9) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.9) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# Virtual Displayの設定

# %%
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
#os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)

# %% [markdown]
# ## Check Space

# %% [markdown]
# 必要なライブラリのインポート

# %%
import gym
import sys
from gym.spaces import *

# %% [markdown]
# 関数の定義

# %%
def print_spaces(space):
    print(space)

    if isinstance(space, Box):
        print('min:', space.low)
        print('max:', space.high)
    if isinstance(space, Discrete):
        print('min:', 0)
        print('max:', space.n-1)

# %% [markdown]
# print_spaces(CartPole-v1)

# %%
env = gym.make('CartPole-v1')
print_spaces(env.action_space)
print_spaces(env.observation_space)
# Out:
# Discrete(2)
# min: 0
# max: 1
# Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# min: [-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38]
# max: [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38]

# %% [markdown]
# ## Cart Pole V1

# %% [markdown]
# 設定

# %%
# 試行回数
EPISODE_NUMB = 3

# 最大試行時間
MAX_TIME = 2000

# %% [markdown]
# 試行

# %%
frames = []
for i in range(EPISODE_NUMB):
    observation = env.reset()  # reset for each new trial
    done = False
    total_reward = 0
    total_time = 0
    while not done and total_time < MAX_TIME: # run for 100 timesteps or until done, whichever is first
        frames.append(env.render(mode = 'rgb_array'))
        action = env.action_space.sample()  # select a random action (see https://github.com/openai/gym/wiki/CartPole-v1)
        observation, reward, done, _ = env.step(action)
        total_reward += reward
        total_time += 1
    print('test episode:', i, 'reward:', total_reward, 'time:', total_time)
 
env.render()
# Out:
# test episode: 0 reward: 48.0 time: 48
# test episode: 1 reward: 19.0 time: 19
# test episode: 2 reward: 22.0 time: 22
# True

# %% [markdown]
# 描画

# %% [markdown]
# インポート

# %%
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np
from IPython.display import HTML

# %% [markdown]
# 描画

# %%
plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img59bbda09145b48578e24cb1bde68e512">
#   <div class="anim-controls">
#     <input id="_anim_slider59bbda09145b48578e24cb1bde68e512" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim59bbda09145b48578e24cb1bde68e512.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim59bbda09145b48578e24cb1bde68e512.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select59bbda09145b48578e24cb1bde68e512" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_59bbda09145b48578e24cb1bde68e512"
#              >
#       <label for="_anim_radio1_59bbda09145b48578e24cb1bde68e512">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_59bbda09145b48578e24cb1bde68e512"
#              checked>
#       <label for="_anim_radio2_59bbda09145b48578e24cb1bde68e512">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_59bbda09145b48578e24cb1bde68e512"
#              >
#       <label for="_anim_radio3_59bbda09145b48578e24cb1bde68e512">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img59bbda09145b48578e24cb1bde68e512";
#     var slider_id = "_anim_slider59bbda09145b48578e24cb1bde68e512";
#     var loop_select_id = "_anim_loop_select59bbda09145b48578e24cb1bde68e512";
#     var frames = new Array(89);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAJj0lEQVR4nO3dv4uceQHH8e+Tzeb20Hh32CTH6lUi\
# sRARuSogWMTOTlJqaesfYCCpbBSFlNfY2VxpJXfdgZhwoIgQiadEcsZzvfXHXczuZvexEBbP3fXH\
# +nZnJ3m9umcenuHTzPCGeWZmmud5HgAAZM4segAAwJNGYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQW\
# AEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBM\
# YAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEA\
# xAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQW\
# AEBMYAEAxAQWAEBMYAEAxAQWAE

# %% [markdown]
# レベル2

# %% [markdown]
# 少し戦略的に試行

# %%
frames = []

high_total_reward = 0
high_reward_episode = 0

for i in range(EPISODE_NUMB):
    observation = env.reset()  # reset for each new trial
    done = False
    total_reward = 0
    total_time = 0
    while not done and total_time < MAX_TIME: # run for 100 timesteps or until done, whichever is first
        frames.append(env.render(mode = 'rgb_array'))
        action = 1 if observation[2] > 0 else 0 # if angle if positive, move right. if angle is negative, move left
        observation, reward, done, _ = env.step(action)
        total_reward += reward
        total_time += 1
        if total_reward > high_total_reward:
          high_total_reward = total_reward
          high_reward_episode = i
    print('test episode:', i, 'reward:', total_reward, 'time:', total_time)
 
print('highscore:', high_total_reward ,'episode:', high_reward_episode)
env.render()
# Out:
# test episode: 0 reward: 60.0 time: 60
# test episode: 1 reward: 25.0 time: 25
# test episode: 2 reward: 41.0 time: 41
# highscore: 60.0 episode: 0
# True

# %% [markdown]
# 描画

# %%
plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img798cd523bc4c48b4a76f6d179d52dd9a">
#   <div class="anim-controls">
#     <input id="_anim_slider798cd523bc4c48b4a76f6d179d52dd9a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim798cd523bc4c48b4a76f6d179d52dd9a.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim798cd523bc4c48b4a76f6d179d52dd9a.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select798cd523bc4c48b4a76f6d179d52dd9a" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_798cd523bc4c48b4a76f6d179d52dd9a"
#              >
#       <label for="_anim_radio1_798cd523bc4c48b4a76f6d179d52dd9a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_798cd523bc4c48b4a76f6d179d52dd9a"
#              checked>
#       <label for="_anim_radio2_798cd523bc4c48b4a76f6d179d52dd9a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_798cd523bc4c48b4a76f6d179d52dd9a"
#              >
#       <label for="_anim_radio3_798cd523bc4c48b4a76f6d179d52dd9a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img798cd523bc4c48b4a76f6d179d52dd9a";
#     var slider_id = "_anim_slider798cd523bc4c48b4a76f6d179d52dd9a";
#     var loop_select_id = "_anim_loop_select798cd523bc4c48b4a76f6d179d52dd9a";
#     var frames = new Array(126);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAJlklEQVR4nO3dz4vcdx3H8fdsNolNtK3WQqKxFVQw\
# qIgHsdCAt/wFhfwRvfgXBJKzx1y8ehY9eumheCgqoUFEIRhpDKQNSTRR+yPZZne8Ndrsii5PMp3m\
# 8bjNfPgOr8sMT2ZndhbL5XI5AABkNlY9AADg00ZgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExg\
# AQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDE\
# BBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYA\
# QExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExg\
# AQDEBBYAQExgAQDEBBYAQExgA

# %% [markdown]
# ## 深層学習

# %% [markdown]
# ライブラリのインストール

# %%
# !pip -q install stable-baselines[mpi]
# Out:
#      |████████████████████████████████| 240 kB 5.3 MB/s
#      |████████████████████████████████| 2.4 MB 34.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#   Building wheel for mpi4py (PEP 517) ... done

# %%
# %tensorflow_version 1.x
import tensorflow as tf
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# モデルの学習

# %%
frames = []
env = gym.make('CartPole-v1')
env = DummyVecEnv([lambda: env])
model = PPO2('MlpPolicy', env, verbose=1)

model.learn(total_timesteps=10000)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/tf_util.py:85: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/tf_util.py:94: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/policies.py:50: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/input.py:26: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/policies.py:260: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/a2c/utils.py:145: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/distributions.py:319: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/common/distributions.py:320: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/ppo2/ppo2.py:158: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/ppo2/ppo2.py:166: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/ppo2/ppo2.py:171: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/ppo2/ppo2.py:178: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/ppo2/ppo2.py:200: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/stable_baselines/ppo2/ppo2.py:202: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | approxkl           | 0.00016452739 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.000617      |
# | fps                | 62            |
# | nupdates           | 2             |
# | policy_entropy     | 0.69297296    |
# | policy_loss        | -0.004092819  |
# | serial_timesteps   | 256           |
# | time_elapsed       | 2.86e-06      |
# | total_timesteps    | 256           |
# | value_loss         | 42.880917     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023146631 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0491        |
# | fps                | 410           |
# | nupdates           | 3             |
# | policy_entropy     | 0.69144404    |
# | policy_loss        | -0.0029322125 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 2.04          |
# | total_timesteps    | 384           |
# | value_loss         | 47.149467     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.855491e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0967        |
# | fps                | 407           |
# | nupdates           | 4             |
# | policy_entropy     | 0.68945825    |
# | policy_loss        | -0.0010353886 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 2.35          |
# | total_timesteps    | 512           |
# | value_loss         | 38.058365     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.9518778e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0163        |
# | fps                | 386           |
# | nupdates           | 5             |
# | policy_entropy     | 0.68936414    |
# | policy_loss        | -0.0008974847 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 2.67          |
# | total_timesteps    | 640           |
# | value_loss         | 50.935196     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.2702965e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0183        |
# | fps                | 398            |
# | nupdates           | 6              |
# | policy_entropy     | 0.68802184     |
# | policy_loss        | -0.00026319316 |
# | serial_timesteps   | 768            |
# | time_elapsed       | 3              |
# | total_timesteps    | 768            |
# | value_loss         | 60.42685       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.1988295e-07 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0123       |
# | fps                | 415           |
# | nupdates           | 7             |
# | policy_entropy     | 0.68858933    |
# | policy_loss        | 9.7933225e-06 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 3.32          |
# | total_timesteps    | 896           |
# | value_loss         | 55.779736     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.066641e-06   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0119         |
# | fps                | 404            |
# | nupdates           | 8              |
# | policy_entropy     | 0.6857636      |
# | policy_loss        | -0.00015298848 |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 3.63           |
# | total_timesteps    | 1024           |
# | value_loss         | 33.78534       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00016168061 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.038         |
# | fps                | 403           |
# | nupdates           | 9             |
# | policy_entropy     | 0.6812082     |
# | policy_loss        | -0.0036288896 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 3.95          |
# | total_timesteps    | 1152          |
# | value_loss         | 62.524498     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004585085 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.0528       |
# | fps                | 386          |
# | nupdates           | 10           |
# | policy_entropy     | 0.67734486   |
# | policy_loss        | -0.00734585  |
# | serial_timesteps   | 1280         |
# | time_elapsed       | 4.27         |
# | total_timesteps    | 1280         |
# | value_loss         | 57.8283      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00022260321 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0784       |
# | fps                | 404           |
# | nupdates           | 11            |
# | policy_entropy     | 0.67238027    |
# | policy_loss        | -0.001051776  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 4.6           |
# | total_timesteps    | 1408          |
# | value_loss         | 49.988888     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002729557  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0183        |
# | fps                | 407           |
# | nupdates           | 12            |
# | policy_entropy     | 0.6688422     |
# | policy_loss        | -0.0012683483 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 4.92          |
# | total_timesteps    | 1536          |
# | value_loss         | 43.79767      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.5822835e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.102        |
# | fps                | 416           |
# | nupdates           | 13            |
# | policy_entropy     | 0.6504657     |
# | policy_loss        | -0.0012104248 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 5.24          |
# | total_timesteps    | 1664          |
# | value_loss         | 75.71602      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.802803e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00674      |
# | fps                | 401           |
# | nupdates           | 14            |
# | policy_entropy     | 0.6636515     |
# | policy_loss        | -0.0001901688 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 5.55          |
# | total_timesteps    | 1792          |
# | value_loss         | 54.684547     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.5489588e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.00815       |
# | fps                | 386            |
# | nupdates           | 15             |
# | policy_entropy     | 0.67022645     |
# | policy_loss        | -0.00016605714 |
# | serial_timesteps   | 1920           |
# | time_elapsed       | 5.87           |
# | total_timesteps    | 1920           |
# | value_loss         | 66.840096      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.2743406e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0514        |
# | fps                | 385           |
# | nupdates           | 16            |
# | policy_entropy     | 0.66717184    |
# | policy_loss        | -0.0005094328 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 6.21          |
# | total_timesteps    | 2048          |
# | value_loss         | 81.73758      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 6.990085e-05 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.0999       |
# | fps                | 382          |
# | nupdates           | 17           |
# | policy_entropy     | 0.6641051    |
# | policy_loss        | 0.0007519196 |
# | serial_timesteps   | 2176         |
# | time_elapsed       | 6.54         |
# | total_timesteps    | 2176         |
# | value_loss         | 43.624718    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00036892202 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00778      |
# | fps                | 398           |
# | nupdates           | 18            |
# | policy_entropy     | 0.6540062     |
# | policy_loss        | -0.0055317124 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 6.88          |
# | total_timesteps    | 2304          |
# | value_loss         | 51.613632     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00078513235 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0135        |
# | fps                | 384           |
# | nupdates           | 19            |
# | policy_entropy     | 0.6512216     |
# | policy_loss        | -0.0054981895 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 7.2           |
# | total_timesteps    | 2432          |
# | value_loss         | 47.425293     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0003258888   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.05          |
# | fps                | 411            |
# | nupdates           | 20             |
# | policy_entropy     | 0.6463036      |
# | policy_loss        | -0.00094874075 |
# | serial_timesteps   | 2560           |
# | time_elapsed       | 7.54           |
# | total_timesteps    | 2560           |
# | value_loss         | 49.125248      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00019782773 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0544       |
# | fps                | 408           |
# | nupdates           | 21            |
# | policy_entropy     | 0.63145113    |
# | policy_loss        | -0.0038505264 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 7.85          |
# | total_timesteps    | 2688          |
# | value_loss         | 43.639843     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012161717 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.165         |
# | fps                | 404           |
# | nupdates           | 22            |
# | policy_entropy     | 0.64397913    |
# | policy_loss        | -0.0003982708 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 8.17          |
# | total_timesteps    | 2816          |
# | value_loss         | 95.30843      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.5673806e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0755        |
# | fps                | 424           |
# | nupdates           | 23            |
# | policy_entropy     | 0.6367213     |
# | policy_loss        | -0.0005300321 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 8.49          |
# | total_timesteps    | 2944          |
# | value_loss         | 78.63971      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013410366 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.104         |
# | fps                | 397           |
# | nupdates           | 24            |
# | policy_entropy     | 0.6172993     |
# | policy_loss        | -0.0011478666 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 8.79          |
# | total_timesteps    | 3072          |
# | value_loss         | 54.56543      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023754075 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0151        |
# | fps                | 421           |
# | nupdates           | 25            |
# | policy_entropy     | 0.6265947     |
# | policy_loss        | -0.0024944367 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 9.12          |
# | total_timesteps    | 3200          |
# | value_loss         | 77.41873      |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.002848601 |
# | clipfrac           | 0.033203125 |
# | ep_rewmean         | nan         |
# | eplenmean          | nan         |
# | explained_variance | -0.0639     |
# | fps                | 390         |
# | nupdates           | 26          |
# | policy_entropy     | 0.60060287  |
# | policy_loss        | 0.009009665 |
# | serial_timesteps   | 3328        |
# | time_elapsed       | 9.42        |
# | total_timesteps    | 3328        |
# | value_loss         | 63.40977    |
# ------------------------------------
# ---------------------------------------
# | approxkl           | 1.7409366e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0573         |
# | fps                | 394            |
# | nupdates           | 27             |
# | policy_entropy     | 0.62413025     |
# | policy_loss        | -0.00024701428 |
# | serial_timesteps   | 3456           |
# | time_elapsed       | 9.76           |
# | total_timesteps    | 3456           |
# | value_loss         | 77.521645      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0001096868  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.211         |
# | fps                | 416           |
# | nupdates           | 28            |
# | policy_entropy     | 0.613787      |
# | policy_loss        | -0.0013769133 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 10.1          |
# | total_timesteps    | 3584          |
# | value_loss         | 55.272064     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.835039e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0787        |
# | fps                | 398           |
# | nupdates           | 29            |
# | policy_entropy     | 0.6032693     |
# | policy_loss        | 0.00066255254 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 10.4          |
# | total_timesteps    | 3712          |
# | value_loss         | 76.730545     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.868436e-06  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0719       |
# | fps                | 405           |
# | nupdates           | 30            |
# | policy_entropy     | 0.58798575    |
# | policy_loss        | -0.0002044614 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 3840          |
# | value_loss         | 77.828415     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.36711e-05   |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0197       |
# | fps                | 395           |
# | nupdates           | 31            |
# | policy_entropy     | 0.6262612     |
# | policy_loss        | -0.0006468437 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 11            |
# | total_timesteps    | 3968          |
# | value_loss         | 75.51323      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005565684  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.179         |
# | fps                | 399           |
# | nupdates           | 32            |
# | policy_entropy     | 0.57232195    |
# | policy_loss        | -0.0032822622 |
# | serial_timesteps   | 4096          |
# | time_elapsed       | 11.4          |
# | total_timesteps    | 4096          |
# | value_loss         | 54.17889      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.5439658e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0322        |
# | fps                | 403           |
# | nupdates           | 33            |
# | policy_entropy     | 0.59593487    |
# | policy_loss        | 0.00025297212 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 11.7          |
# | total_timesteps    | 4224          |
# | value_loss         | 56.543053     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.7226633e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.018         |
# | fps                | 397           |
# | nupdates           | 34            |
# | policy_entropy     | 0.5895861     |
# | policy_loss        | -0.0015051856 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 12            |
# | total_timesteps    | 4352          |
# | value_loss         | 48.742184     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.2415234e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0212       |
# | fps                | 400           |
# | nupdates           | 35            |
# | policy_entropy     | 0.58444506    |
# | policy_loss        | -0.002029297  |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 12.3          |
# | total_timesteps    | 4480          |
# | value_loss         | 51.41676      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013378076 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0126       |
# | fps                | 386           |
# | nupdates           | 36            |
# | policy_entropy     | 0.5941131     |
# | policy_loss        | -0.0016199462 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 4608          |
# | value_loss         | 78.40101      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.247379e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00108      |
# | fps                | 392           |
# | nupdates           | 37            |
# | policy_entropy     | 0.58450234    |
# | policy_loss        | -0.0004520903 |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 13            |
# | total_timesteps    | 4736          |
# | value_loss         | 48.1368       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.4369525e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0696       |
# | fps                | 390           |
# | nupdates           | 38            |
# | policy_entropy     | 0.60055745    |
# | policy_loss        | -0.0012864977 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 13.3          |
# | total_timesteps    | 4864          |
# | value_loss         | 70.0815       |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000103584345 |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0333        |
# | fps                | 396            |
# | nupdates           | 39             |
# | policy_entropy     | 0.5660274      |
# | policy_loss        | -0.0009144973  |
# | serial_timesteps   | 4992           |
# | time_elapsed       | 13.7           |
# | total_timesteps    | 4992           |
# | value_loss         | 61.79846       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.099152e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0914         |
# | fps                | 402            |
# | nupdates           | 40             |
# | policy_entropy     | 0.6017059      |
# | policy_loss        | -0.00030373572 |
# | serial_timesteps   | 5120           |
# | time_elapsed       | 14             |
# | total_timesteps    | 5120           |
# | value_loss         | 67.140686      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00026974373 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.274         |
# | fps                | 406           |
# | nupdates           | 41            |
# | policy_entropy     | 0.5733297     |
# | policy_loss        | 0.0021448135  |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 14.3          |
# | total_timesteps    | 5248          |
# | value_loss         | 75.107574     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2690094e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.348         |
# | fps                | 386           |
# | nupdates           | 42            |
# | policy_entropy     | 0.61689484    |
# | policy_loss        | 0.0003684624  |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 14.6          |
# | total_timesteps    | 5376          |
# | value_loss         | 86.31022      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001094849  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.45          |
# | fps                | 396           |
# | nupdates           | 43            |
# | policy_entropy     | 0.61945415    |
# | policy_loss        | 0.00020495546 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 15            |
# | total_timesteps    | 5504          |
# | value_loss         | 68.38649      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.4615314e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0338        |
# | fps                | 408           |
# | nupdates           | 44            |
# | policy_entropy     | 0.5862399     |
# | policy_loss        | 0.0005098229  |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 15.3          |
# | total_timesteps    | 5632          |
# | value_loss         | 61.91596      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.307008e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0205         |
# | fps                | 414            |
# | nupdates           | 45             |
# | policy_entropy     | 0.61167717     |
# | policy_loss        | -0.00080573873 |
# | serial_timesteps   | 5760           |
# | time_elapsed       | 15.6           |
# | total_timesteps    | 5760           |
# | value_loss         | 61.36931       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.616047e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.419         |
# | fps                | 386           |
# | nupdates           | 46            |
# | policy_entropy     | 0.57632923    |
# | policy_loss        | 0.00010211993 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 15.9          |
# | total_timesteps    | 5888          |
# | value_loss         | 58.378036     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00074449414 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.457         |
# | fps                | 395           |
# | nupdates           | 47            |
# | policy_entropy     | 0.60222316    |
# | policy_loss        | -0.0013685694 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 16.2          |
# | total_timesteps    | 6016          |
# | value_loss         | 59.201317     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00028027437 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.322         |
# | fps                | 406           |
# | nupdates           | 48            |
# | policy_entropy     | 0.58608776    |
# | policy_loss        | -0.0019030711 |
# | serial_timesteps   | 6144          |
# | time_elapsed       | 16.6          |
# | total_timesteps    | 6144          |
# | value_loss         | 63.022434     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00061309035 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.503         |
# | fps                | 383           |
# | nupdates           | 49            |
# | policy_entropy     | 0.59255385    |
# | policy_loss        | -0.0009895929 |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 16.9          |
# | total_timesteps    | 6272          |
# | value_loss         | 58.62501      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012610477 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.00205      |
# | fps                | 388           |
# | nupdates           | 50            |
# | policy_entropy     | 0.58041227    |
# | policy_loss        | -0.0016104688 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 17.2          |
# | total_timesteps    | 6400          |
# | value_loss         | 60.451664     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016787271 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0146        |
# | fps                | 392           |
# | nupdates           | 51            |
# | policy_entropy     | 0.61185384    |
# | policy_loss        | -0.000372333  |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 17.6          |
# | total_timesteps    | 6528          |
# | value_loss         | 83.081726     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0018345418   |
# | clipfrac           | 0.00390625     |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0406         |
# | fps                | 383            |
# | nupdates           | 52             |
# | policy_entropy     | 0.5857237      |
# | policy_loss        | -0.00041051186 |
# | serial_timesteps   | 6656           |
# | time_elapsed       | 17.9           |
# | total_timesteps    | 6656           |
# | value_loss         | 82.1806        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00040009976 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0423       |
# | fps                | 409           |
# | nupdates           | 53            |
# | policy_entropy     | 0.5879657     |
# | policy_loss        | -0.0024508098 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 18.2          |
# | total_timesteps    | 6784          |
# | value_loss         | 76.7389       |
# --------------------------------------
# -------------------------------------
# | approxkl           | 6.987999e-05 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.6          |
# | fps                | 411          |
# | nupdates           | 54           |
# | policy_entropy     | 0.59243125   |
# | policy_loss        | 0.0010812841 |
# | serial_timesteps   | 6912         |
# | time_elapsed       | 18.5         |
# | total_timesteps    | 6912         |
# | value_loss         | 55.46116     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 2.4911187e-05  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0441        |
# | fps                | 439            |
# | nupdates           | 55             |
# | policy_entropy     | 0.5941157      |
# | policy_loss        | -0.00060745655 |
# | serial_timesteps   | 7040           |
# | time_elapsed       | 18.8           |
# | total_timesteps    | 7040           |
# | value_loss         | 57.68335       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.619967e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.247        |
# | fps                | 392           |
# | nupdates           | 56            |
# | policy_entropy     | 0.59240705    |
# | policy_loss        | -0.0008527142 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 19.1          |
# | total_timesteps    | 7168          |
# | value_loss         | 84.27134      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.672194e-06  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0109       |
# | fps                | 392           |
# | nupdates           | 57            |
# | policy_entropy     | 0.5568284     |
# | policy_loss        | 9.0890564e-05 |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 19.5          |
# | total_timesteps    | 7296          |
# | value_loss         | 39.020756     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.9570136e-06  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0244         |
# | fps                | 408            |
# | nupdates           | 58             |
# | policy_entropy     | 0.5815492      |
# | policy_loss        | -0.00021928828 |
# | serial_timesteps   | 7424           |
# | time_elapsed       | 19.8           |
# | total_timesteps    | 7424           |
# | value_loss         | 58.6061        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.974953e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.543         |
# | fps                | 380           |
# | nupdates           | 59            |
# | policy_entropy     | 0.5635357     |
# | policy_loss        | -0.0004045181 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 20.1          |
# | total_timesteps    | 7552          |
# | value_loss         | 50.167534     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015283304  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.225         |
# | fps                | 383           |
# | nupdates           | 60            |
# | policy_entropy     | 0.56621236    |
# | policy_loss        | 0.00042633794 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 20.4          |
# | total_timesteps    | 7680          |
# | value_loss         | 63.19757      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.734747e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.242         |
# | fps                | 414           |
# | nupdates           | 61            |
# | policy_entropy     | 0.5488106     |
# | policy_loss        | -0.0007280874 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 20.8          |
# | total_timesteps    | 7808          |
# | value_loss         | 51.8451       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013006615 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.515         |
# | fps                | 414           |
# | nupdates           | 62            |
# | policy_entropy     | 0.55671144    |
# | policy_loss        | -0.0011285401 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 21.1          |
# | total_timesteps    | 7936          |
# | value_loss         | 48.612835     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00011022245  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0593         |
# | fps                | 415            |
# | nupdates           | 63             |
# | policy_entropy     | 0.58225805     |
# | policy_loss        | -0.00019665528 |
# | serial_timesteps   | 8064           |
# | time_elapsed       | 21.4           |
# | total_timesteps    | 8064           |
# | value_loss         | 56.086998      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.470238e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0676        |
# | fps                | 417            |
# | nupdates           | 64             |
# | policy_entropy     | 0.5867989      |
# | policy_loss        | -0.00038556126 |
# | serial_timesteps   | 8192           |
# | time_elapsed       | 21.7           |
# | total_timesteps    | 8192           |
# | value_loss         | 78.48448       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.316747e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.525         |
# | fps                | 388           |
# | nupdates           | 65            |
# | policy_entropy     | 0.58675414    |
# | policy_loss        | 2.2077467e-05 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 22            |
# | total_timesteps    | 8320          |
# | value_loss         | 48.505573     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.3656323e-06  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | -0.0225        |
# | fps                | 398            |
# | nupdates           | 66             |
# | policy_entropy     | 0.60399365     |
# | policy_loss        | -0.00020501507 |
# | serial_timesteps   | 8448           |
# | time_elapsed       | 22.3           |
# | total_timesteps    | 8448           |
# | value_loss         | 76.46567       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.2568041e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.15          |
# | fps                | 414           |
# | nupdates           | 67            |
# | policy_entropy     | 0.613286      |
# | policy_loss        | 0.00027029286 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 22.7          |
# | total_timesteps    | 8576          |
# | value_loss         | 74.145546     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009949674 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | -0.163       |
# | fps                | 408          |
# | nupdates           | 68           |
# | policy_entropy     | 0.58844364   |
# | policy_loss        | -0.004475675 |
# | serial_timesteps   | 8704         |
# | time_elapsed       | 23           |
# | total_timesteps    | 8704         |
# | value_loss         | 77.4505      |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007986604 |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | -0.000414    |
# | fps                | 396          |
# | nupdates           | 69           |
# | policy_entropy     | 0.5695099    |
# | policy_loss        | 0.0015663183 |
# | serial_timesteps   | 8832         |
# | time_elapsed       | 23.3         |
# | total_timesteps    | 8832         |
# | value_loss         | 55.41208     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 2.662479e-05   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.0427         |
# | fps                | 404            |
# | nupdates           | 70             |
# | policy_entropy     | 0.5433945      |
# | policy_loss        | -0.00093536475 |
# | serial_timesteps   | 8960           |
# | time_elapsed       | 23.6           |
# | total_timesteps    | 8960           |
# | value_loss         | 59.189842      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.6301212e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.509         |
# | fps                | 390           |
# | nupdates           | 71            |
# | policy_entropy     | 0.576695      |
# | policy_loss        | 0.0002311857  |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 23.9          |
# | total_timesteps    | 9088          |
# | value_loss         | 46.963795     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.70076e-05  |
# | clipfrac           | 0.0          |
# | ep_rewmean         | nan          |
# | eplenmean          | nan          |
# | explained_variance | 0.118        |
# | fps                | 419          |
# | nupdates           | 72           |
# | policy_entropy     | 0.6036288    |
# | policy_loss        | 1.375156e-05 |
# | serial_timesteps   | 9216         |
# | time_elapsed       | 24.3         |
# | total_timesteps    | 9216         |
# | value_loss         | 71.59586     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00018561805 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.533         |
# | fps                | 402           |
# | nupdates           | 73            |
# | policy_entropy     | 0.5890832     |
# | policy_loss        | -0.0019003609 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 24.6          |
# | total_timesteps    | 9344          |
# | value_loss         | 45.061607     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6513666e-05 |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.0635        |
# | fps                | 392           |
# | nupdates           | 74            |
# | policy_entropy     | 0.5742333     |
# | policy_loss        | 0.00040152005 |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 24.9          |
# | total_timesteps    | 9472          |
# | value_loss         | 70.54999      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.474642e-05  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.615         |
# | fps                | 380           |
# | nupdates           | 75            |
# | policy_entropy     | 0.6057002     |
# | policy_loss        | 0.00015359977 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 25.2          |
# | total_timesteps    | 9600          |
# | value_loss         | 42.255386     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.73372e-06   |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | -0.0439       |
# | fps                | 396           |
# | nupdates           | 76            |
# | policy_entropy     | 0.5840615     |
# | policy_loss        | -3.785768e-05 |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 25.6          |
# | total_timesteps    | 9728          |
# | value_loss         | 70.48266      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00016578397  |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.00421        |
# | fps                | 407            |
# | nupdates           | 77             |
# | policy_entropy     | 0.6156096      |
# | policy_loss        | -0.00066603743 |
# | serial_timesteps   | 9856           |
# | time_elapsed       | 25.9           |
# | total_timesteps    | 9856           |
# | value_loss         | 58.419357      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.996214e-06   |
# | clipfrac           | 0.0            |
# | ep_rewmean         | nan            |
# | eplenmean          | nan            |
# | explained_variance | 0.366          |
# | fps                | 397            |
# | nupdates           | 78             |
# | policy_entropy     | 0.5698251      |
# | policy_loss        | -0.00038904976 |
# | serial_timesteps   | 9984           |
# | time_elapsed       | 26.2           |
# | total_timesteps    | 9984           |
# | value_loss         | 66.132866      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0006497247  |
# | clipfrac           | 0.0           |
# | ep_rewmean         | nan           |
# | eplenmean          | nan           |
# | explained_variance | 0.656         |
# | fps                | 397           |
# | nupdates           | 79            |
# | policy_entropy     | 0.5676521     |
# | policy_loss        | -0.0056899586 |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 26.5          |
# | total_timesteps    | 10112         |
# | value_loss         | 48.29301      |
# --------------------------------------

# %% [markdown]
# 試行

# %%
state = env.reset()

for i in range(2000):
    frames.append(env.render(mode = 'rgb_array'))

    action, _ = model.predict(state, deterministic=True)

    state, rewards, done, info = env.step(action)

    if done:
        break

env.close()

# %% [markdown]
# 描画

# %%
plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb526e80d66b0437e8176293358f5c834">
#   <div class="anim-controls">
#     <input id="_anim_sliderb526e80d66b0437e8176293358f5c834" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb526e80d66b0437e8176293358f5c834.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animb526e80d66b0437e8176293358f5c834.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animb526e80d66b0437e8176293358f5c834.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectb526e80d66b0437e8176293358f5c834" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b526e80d66b0437e8176293358f5c834"
#              >
#       <label for="_anim_radio1_b526e80d66b0437e8176293358f5c834">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b526e80d66b0437e8176293358f5c834"
#              checked>
#       <label for="_anim_radio2_b526e80d66b0437e8176293358f5c834">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b526e80d66b0437e8176293358f5c834"
#              >
#       <label for="_anim_radio3_b526e80d66b0437e8176293358f5c834">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb526e80d66b0437e8176293358f5c834";
#     var slider_id = "_anim_sliderb526e80d66b0437e8176293358f5c834";
#     var loop_select_id = "_anim_loop_selectb526e80d66b0437e8176293358f5c834";
#     var frames = new Array(310);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAKKUlEQVR4nO3dz4ucdwHH8e+z2W1N67alhdCYqqUK\
# kqDUXwfRCEWkeurBg4hX8dQ/wEvpoSfJqf+E6MWDehEFEUQrXjQtqAm00rrQbWOpddvYNLv7eLFS\
# SZaS8O5OZ+f1uu3znVk+lxnezM7OTPM8zwMAgMzaogcAABw1AgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAI
