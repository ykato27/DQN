# %% [markdown]
# <a href="https://colab.research.google.com/github/ykato27/Reinforcement-Learning/blob/main/01_Deep_Q_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 目的
# Deep Q-networkの仕組みを理解し，ゲームタスクを用いて強化学習をおこなう．\
# 学習後のエージェントの可視化を行い，学習がうまくできているか確認を行う．

# %% [markdown]
# # Deep Q-Network(DQN)
# Deep Q-Network(DQN)は，GoogleのDeep mindチームが2016年に発表した手法で，Q学習におけるQテーブルを用いた行動価値の導出をDCNNを用いた近似関数で代用するのが主な手法の内容である．それまでのQ学習ではすべての状態と行動に組み合わせについての行動価値をQテーブルに記録していたために状態数と行動数の組み合わせが膨大な環境に対して膨大なメモリが必要となる問題を抱えていました．これに対してDQNはQテーブルそのものをDCNNで代用することにより膨大な行動数と状態数の組み合わせが存在する環境に対しても学習を行うことが可能となり，atari2600のゲーム環境において人間を超えるスコアを出すことに成功している．また，DQNにはその他にも強化学習における学習の安定性獲得のためにExperience replay，Target Q-Network，reward_clippingなどの工夫がなされている．行動価値関数(Q値)を用いて行動を決定し，最適行動価値関数になるよう更新を行っていく手法は，価値ベースの手法と呼ばれている．派生手法には，DDQN，Ape-X，R2D2などの手法がある．\
# <img src="http://drive.google.com/uc?export=view&id=1J7YPwb1iMd4eKo3YKLc7Rk4XG-vT7hoz" width = 50%>

# %% [markdown]
# ## 準備
#
# ### Google Colaboratoryの設定確認・変更
# 本チュートリアルではPyTorchを利用してニューラルネットワークの実装を確認，学習および評価を行います．
# **GPUを用いて処理を行うために，上部のメニューバーの「ランタイム」→「ランタイムのタイプを変更」からハードウェアアクセラレータをGPUにしてください．**
#
#
# ### モジュールの追加インストール
# 下記のプログラムを実行して，実験結果の表示に必要な追加ライブラリやモジュールをインストールする．

# %%
# !apt-get -qq -y install libcusparse9.1 libnvrtc9.1 libnvtoolsext1 > /dev/null
# !ln -snf /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so.9.1 /usr/lib/x86_64-linux-gnu/libnvrtc-builtins.so
# !apt-get -qq -y install xvfb freeglut3-dev ffmpeg> /dev/null

# !pip -q install gym
# !pip -q install pyglet
# !pip -q install pyopengl
# !pip -q install pyvirtualdisplay

# %% [markdown]
# ## モジュールのインポート
# はじめに必要なモジュールをインポートする．
#
# 今回はPyTorchに加えて，Cart Poleを実行するためのシミュレータであるopenAI Gym（gym）をインポートする．

# %%
import numpy as np
import gym
import gym.spaces

import time
import math
import random
import cv2
import matplotlib
import matplotlib.pyplot as plt
import collections
from itertools import count
from PIL import Image
# %matplotlib inline

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# 使用するデバイス（GPU or CPU）の決定
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Use device:", device)
# Out:
# Use device: cuda

# %% [markdown]
# ## OpenAI GymによるPongの環境の定義
#  [OpenAI Gym](https://github.com/openai/gym) は，様々な種類の環境を提供しているモジュールです．
#
#  今回はgymで利用できるatariゲームであるPongを実行します．
#  まず，gym.make関数で実行したい環境を指定します．
#  その後，reset関数を実行することで，環境を初期化します．
#
# Pong環境は，パドルを操作してボールが自分の陣地に入らないように打ち返すゲームです．Pong環境において現在の状態を確認するためにゲームの画面情報が与えられており，`observation_space`という変数で確認することができます．
# また，`action_space`という変数で，エージェントが取ることのできる行動の数を確認することができます．
# Pongの場合は，パドルを上下どちらかに移動させるという行動を取るため，行動の数は2となっています．
# Pongのゲーム概要は，相手の陣地にボールを入れることで得点を獲得し，ボールを自分の陣地に入れられることで得点を取られます．どちらかのプレイヤーが21点取った時点で終了となります．

# %%
# 環境の指定
env = gym.make('CartPole-v0')

# 環境の初期化
obs = env.reset()
#env.render()
print('observation space:', env.observation_space)
print('action space:', env.action_space)
print('initial observation:', obs)

# 行動の決定と決定した行動の入力
action = env.action_space.sample()
obs, r, done, info = env.step(action)
print('next observation:', obs)
print('reward:', r)
print('done:', done)
print('info:', info)
# Out:
# observation space: Box(-3.4028234663852886e+38, 3.4028234663852886e+38, (4,), float32)
# action space: Discrete(2)
# initial observation: [ 0.03408701 -0.03194897  0.03500863 -0.00663642]
# next observation: [ 0.03344803 -0.22755505  0.0348759   0.29688335]
# reward: 1.0
# done: False
# info: {}

# %% [markdown]
# ## ネットワーク構造
# ネットワークモデルを定義します． ここでは，環境からのゲーム画面情報を入力し，行動に対するQ値を出力するようなネットワークを定義するために，畳み込み層3層と全結合層2層から構成されるネットワークとします．
#
# 入力データのサイズをinput_shape，出力する行動の数をn_actionsとし，ネットワークの作成時に変更できるようにしておきます．

# %%
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(input_shape)
        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        return self.fc(conv_out)

# %% [markdown]
# ## Deep Q-Networkにおける学習工夫の定義
#
# Deep Q-Networkでは学習の促進と安定化の為に，いくつ工夫を施して学習を行っています．代表的な工夫としてExperience Replay, Target Q-Network, Reward Clippingと呼ばれる3つの工夫があります．

# %% [markdown]
# ### Experience Replay
# DQNは環境の状態を直接観測するのではなく一度Replay Bufferと呼ばれるBufferに経験を格納しておき，学習する際に格納したランダムな経験を取ってくることによって学習を行っています．これをExperience Replayと呼びデータの再利用をおこなうことで，データ効率を高め効率的な学習をおこないます．ここでは，replay memoryの定義を行います．
#
# memoryへは，現在の状態，その時に選択された行動，行動によって遷移した状態（次状態），その時の報酬の4種類の情報を1つの経験として蓄積します． まず，Experienceという変数を定義します． ここでは，state, action, reward, done, next_stateが1セットとなるようなデータ構造（辞書オブジェクト）を定義します．
#
# その後Experience Bufferクラスを定義します． Experience Bufferクラスでは，memoryへ格納する経験の数（capacity），経験を蓄積するbuffer（buffer）を定義します． append関数では，メモリへ経験を格納します． また，sample関数では，指定したバッチサイズ (batch_size) 分の経験をランダムに選択し，返す関数を定義します．

# %%
Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])

class ExperienceBuffer:
    def __init__(self, capacity):
        self.buffer = collections.deque(maxlen=capacity)

    def __len__(self):
        return len(self.buffer)

    def append(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        indices = np.random.choice(len(self.buffer), batch_size, replace=False)
        states, actions, rewards, dones, next_states = zip(*[self.buffer[idx] for idx in indices])
        return np.array(states), np.array(actions), np.array(rewards, dtype=np.float32), \
               np.array(dones, dtype=np.uint8), np.array(next_states)

# %% [markdown]
# ### Target Q-Network
# 強化学習で誤差を計算する際，目標値として使用される行動価値関数と現在の行動価値関数をそれぞれ別のネットワークの出力を用いて誤差を計算します．目標値の行動価値関数を出力するネットワークは一定周期経過するまで固定したネットワークとし，一定周期で現在のネットワークと同期しながら学習を行う工夫がTarget Q-Networkです．この工夫により，学習の安定化を図ります．
#
# target_netを現在のnetと同期するsync_networkを定義します．

# %%
def sync_network():
    tgt_net.load_state_dict(net.state_dict())

# %% [markdown]
# ### reward clipping
# 学習における報酬値を −1 から 1 の範囲に指定します．これにより,学習における外れ値に対する過剰反応を防ぐことができます.
#
# reward clippingは環境に直接ラップするためwrapperクラスを定義します．reward関数では，環境から受け取った報酬を-1から1の範囲にクリップします．

# %%
class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)

# %% [markdown]
# ## その他の学習に必要な処理
# gymのatari環境で学習の安定化と効率的な学習を行うための処理をいくつか行います．

# %%
class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env=None, skip=4):
        """Return only every `skip`-th frame"""
        super(MaxAndSkipEnv, self).__init__(env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = collections.deque(maxlen=2)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = None
        for _ in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            self._obs_buffer.append(obs)
            total_reward += reward
            if done:
                break
        max_frame = np.max(np.stack(self._obs_buffer), axis=0)
        return max_frame, total_reward, done, info

class FireResetEnv(gym.Wrapper):
    def __init__(self, env=None):
        """For environments where the user need to press FIRE for the game to start."""
        super(FireResetEnv, self).__init__(env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def step(self, action):
        return self.env.step(action)

    def reset(self):
        self.env.reset()
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset()
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset()
        return obs

class ProcessFrame84(gym.ObservationWrapper):
    def __init__(self, env=None):
        super(ProcessFrame84, self).__init__(env)
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)

    def observation(self, obs):
        return ProcessFrame84.process(obs)

    @staticmethod
    def process(frame):
        if frame.size == 210 * 160 * 3:
            img = np.reshape(frame, [210, 160, 3]).astype(np.float32)
        elif frame.size == 250 * 160 * 3:
            img = np.reshape(frame, [250, 160, 3]).astype(np.float32)
        else:
            assert False, "Unknown resolution."
        img = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
        resized_screen = cv2.resize(img, (84, 110), interpolation=cv2.INTER_AREA)
        x_t = resized_screen[18:102, :]
        x_t = np.reshape(x_t, [84, 84, 1])
        return x_t.astype(np.uint8)

class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(old_shape[-1], old_shape[0], old_shape[1]),
                                                dtype=np.float32)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)


class ScaledFloatFrame(gym.ObservationWrapper):
    def observation(self, obs):
        return np.array(obs).astype(np.float32) / 255.0


class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps, dtype=np.float32):
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(old_space.low.repeat(n_steps, axis=0),
                                                old_space.high.repeat(n_steps, axis=0), dtype=dtype)

    def reset(self):
        self.buffer = np.zeros_like(self.observation_space.low, dtype=self.dtype)
        return self.observation(self.env.reset())

    def observation(self, observation):
        self.buffer[:-1] = self.buffer[1:]
        self.buffer[-1] = observation
        return self.buffer

# %% [markdown]
# ### 学習に必要な処理の適用
# 環境に対して必要となるそれぞれの処理を作成した環境に対して適用します．

# %%
import urllib.request
urllib.request.urlretrieve('http://www.atarimania.com/roms/Roms.rar','Roms.rar')
# !pip install unrar
# !unrar x Roms.rar
# !mkdir rars
# !mv HC\ ROMS.zip   rars
# !mv ROMS.zip  rars
# !python -m atari_py.import_roms rars
# Out:
# Collecting unrar
#   Downloading unrar-0.4-py3-none-any.whl (25 kB)
# Installing collected packages: unrar
# Successfully installed unrar-0.4
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Roms.rar
#
#   OK
#   OK
# All OK
# copying adventure.bin from HC ROMS/BY ALPHABET (PAL)/A-G/Adventure (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/adventure.bin
# copying air_raid.bin from HC ROMS/BY ALPHABET (PAL)/A-G/Air Raid (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/air_raid.bin
# copying alien.bin from HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Alien.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/alien.bin
# copying crazy_climber.bin from HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Crazy Climber.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/crazy_climber.bin
# copying elevator_action.bin from HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Elevator Action (Prototype).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/elevator_action.bin
# copying gravitar.bin from HC ROMS/BY ALPHABET (PAL)/A-G/REMAINING NTSC ORIGINALS/Gravitar.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gravitar.bin
# copying keystone_kapers.bin from HC ROMS/BY ALPHABET (PAL)/H-R/Keystone Kapers (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/keystone_kapers.bin
# copying king_kong.bin from HC ROMS/BY ALPHABET (PAL)/H-R/King Kong (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/king_kong.bin
# copying laser_gates.bin from HC ROMS/BY ALPHABET (PAL)/H-R/Laser Gates (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/laser_gates.bin
# copying mr_do.bin from HC ROMS/BY ALPHABET (PAL)/H-R/Mr. Do! (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/mr_do.bin
# copying pacman.bin from HC ROMS/BY ALPHABET (PAL)/H-R/Pac-Man (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pacman.bin
# copying jamesbond.bin from HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/James Bond 007.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/jamesbond.bin
# copying koolaid.bin from HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Kool-Aid Man.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/koolaid.bin
# copying krull.bin from HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Krull.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/krull.bin
# copying montezuma_revenge.bin from HC ROMS/BY ALPHABET (PAL)/H-R/REMAINING NTSC ORIGINALS/Montezuma's Revenge - Featuring Panama Joe.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying star_gunner.bin from HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Stargunner.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/star_gunner.bin
# copying time_pilot.bin from HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Time Pilot.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/time_pilot.bin
# copying up_n_down.bin from HC ROMS/BY ALPHABET (PAL)/S-Z/REMAINING NTSC ORIGINALS/Up 'n Down.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/up_n_down.bin
# copying sir_lancelot.bin from HC ROMS/BY ALPHABET (PAL)/S-Z/Sir Lancelot (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/sir_lancelot.bin
# copying amidar.bin from HC ROMS/BY ALPHABET/A-G/Amidar.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/amidar.bin
# copying asteroids.bin from HC ROMS/BY ALPHABET/A-G/Asteroids [no copyright].bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asteroids.bin
# copying atlantis.bin from HC ROMS/BY ALPHABET/A-G/Atlantis.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/atlantis.bin
# copying bank_heist.bin from HC ROMS/BY ALPHABET/A-G/Bank Heist.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bank_heist.bin
# copying battle_zone.bin from HC ROMS/BY ALPHABET/A-G/Battlezone.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/battle_zone.bin
# copying beam_rider.bin from HC ROMS/BY ALPHABET/A-G/Beamrider.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/beam_rider.bin
# copying berzerk.bin from HC ROMS/BY ALPHABET/A-G/Berzerk.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/berzerk.bin
# copying bowling.bin from HC ROMS/BY ALPHABET/A-G/Bowling.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/bowling.bin
# copying boxing.bin from HC ROMS/BY ALPHABET/A-G/Boxing.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/boxing.bin
# copying breakout.bin from HC ROMS/BY ALPHABET/A-G/Breakout - Breakaway IV.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/breakout.bin
# copying carnival.bin from HC ROMS/BY ALPHABET/A-G/Carnival.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/carnival.bin
# copying centipede.bin from HC ROMS/BY ALPHABET/A-G/Centipede.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/centipede.bin
# copying chopper_command.bin from HC ROMS/BY ALPHABET/A-G/Chopper Command.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/chopper_command.bin
# copying defender.bin from HC ROMS/BY ALPHABET/A-G/Defender.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/defender.bin
# copying demon_attack.bin from HC ROMS/BY ALPHABET/A-G/Demon Attack.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/demon_attack.bin
# copying donkey_kong.bin from HC ROMS/BY ALPHABET/A-G/Donkey Kong.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/donkey_kong.bin
# copying double_dunk.bin from HC ROMS/BY ALPHABET/A-G/Double Dunk.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/double_dunk.bin
# copying enduro.bin from HC ROMS/BY ALPHABET/A-G/Enduro.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/enduro.bin
# copying fishing_derby.bin from HC ROMS/BY ALPHABET/A-G/Fishing Derby.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/fishing_derby.bin
# copying freeway.bin from HC ROMS/BY ALPHABET/A-G/Freeway.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/freeway.bin
# copying frogger.bin from HC ROMS/BY ALPHABET/A-G/Frogger.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frogger.bin
# copying frostbite.bin from HC ROMS/BY ALPHABET/A-G/Frostbite.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/frostbite.bin
# copying galaxian.bin from HC ROMS/BY ALPHABET/A-G/Galaxian.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/galaxian.bin
# copying gopher.bin from HC ROMS/BY ALPHABET/A-G/Gopher.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/gopher.bin
# copying hero.bin from HC ROMS/BY ALPHABET/H-R/H.E.R.O..bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/hero.bin
# copying ice_hockey.bin from HC ROMS/BY ALPHABET/H-R/Ice Hockey.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ice_hockey.bin
# copying journey_escape.bin from HC ROMS/BY ALPHABET/H-R/Journey Escape.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/journey_escape.bin
# copying kaboom.bin from HC ROMS/BY ALPHABET/H-R/Kaboom!.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kaboom.bin
# copying kangaroo.bin from HC ROMS/BY ALPHABET/H-R/Kangaroo.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kangaroo.bin
# copying kung_fu_master.bin from HC ROMS/BY ALPHABET/H-R/Kung-Fu Master.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/kung_fu_master.bin
# copying lost_luggage.bin from HC ROMS/BY ALPHABET/H-R/Lost Luggage [no opening scene].bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/lost_luggage.bin
# copying ms_pacman.bin from HC ROMS/BY ALPHABET/H-R/Ms. Pac-Man.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/ms_pacman.bin
# copying name_this_game.bin from HC ROMS/BY ALPHABET/H-R/Name This Game.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/name_this_game.bin
# copying phoenix.bin from HC ROMS/BY ALPHABET/H-R/Phoenix.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/phoenix.bin
# copying pitfall.bin from HC ROMS/BY ALPHABET/H-R/Pitfall! - Pitfall Harry's Jungle Adventure.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pitfall.bin
# copying pooyan.bin from HC ROMS/BY ALPHABET/H-R/Pooyan.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pooyan.bin
# copying private_eye.bin from HC ROMS/BY ALPHABET/H-R/Private Eye.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/private_eye.bin
# copying qbert.bin from HC ROMS/BY ALPHABET/H-R/Q-bert.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/qbert.bin
# copying riverraid.bin from HC ROMS/BY ALPHABET/H-R/River Raid.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/riverraid.bin
# copying road_runner.bin from patched version of HC ROMS/BY ALPHABET/H-R/Road Runner.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/road_runner.bin
# copying robotank.bin from HC ROMS/BY ALPHABET/H-R/Robot Tank.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/robotank.bin
# copying seaquest.bin from HC ROMS/BY ALPHABET/S-Z/Seaquest.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/seaquest.bin
# copying skiing.bin from HC ROMS/BY ALPHABET/S-Z/Skiing.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/skiing.bin
# copying solaris.bin from HC ROMS/BY ALPHABET/S-Z/Solaris.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/solaris.bin
# copying space_invaders.bin from HC ROMS/BY ALPHABET/S-Z/Space Invaders.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/space_invaders.bin
# copying surround.bin from HC ROMS/BY ALPHABET/S-Z/Surround - Chase.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/surround.bin
# copying tennis.bin from HC ROMS/BY ALPHABET/S-Z/Tennis.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tennis.bin
# copying trondead.bin from HC ROMS/BY ALPHABET/S-Z/TRON - Deadly Discs.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/trondead.bin
# copying tutankham.bin from HC ROMS/BY ALPHABET/S-Z/Tutankham.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tutankham.bin
# copying venture.bin from HC ROMS/BY ALPHABET/S-Z/Venture.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/venture.bin
# copying pong.bin from HC ROMS/BY ALPHABET/S-Z/Video Olympics - Pong Sports.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/pong.bin
# copying video_pinball.bin from HC ROMS/BY ALPHABET/S-Z/Video Pinball - Arcade Pinball.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/video_pinball.bin
# copying wizard_of_wor.bin from HC ROMS/BY ALPHABET/S-Z/Wizard of Wor.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/wizard_of_wor.bin
# copying yars_revenge.bin from HC ROMS/BY ALPHABET/S-Z/Yars' Revenge.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/yars_revenge.bin
# copying zaxxon.bin from HC ROMS/BY ALPHABET/S-Z/Zaxxon.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/zaxxon.bin
# copying assault.bin from HC ROMS/NTSC VERSIONS OF PAL ORIGINALS/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/assault.bin
# copying asterix.bin from ROMS/Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/asterix.bin

# %%
env = gym.make("PongNoFrameskip-v4")
env = ClipRewardEnv(env)
env = MaxAndSkipEnv(env)
env = FireResetEnv(env)
env = ProcessFrame84(env)
env = ImageToPyTorch(env)
env = BufferWrapper(env, 4)
env = ScaledFloatFrame(env)

# %% [markdown]
# ## エージェントの定義
# エージェントが環境に対して行動価値に沿った行動を行い，環境から経験を取得し，Experience Buffer記録にするようにします．
#
# エージェントの環境に対する動きのクラスを定義します．play_step関数は，環境にたいして行動を決定する関数です．epsilon-greedy法を用いて一定の割合でランダムに行動選択を行います．それ以外の場合は，使用しているネットワークへ環境情報を入力し，行動を決定します．

# %%
class Agent:
    def __init__(self, env, exp_buffer):
        self.env = env
        self.exp_buffer = exp_buffer
        self._reset()

    def _reset(self):
        self.state = env.reset()
        self.total_reward = 0.0

    def play_step(self, net=None, epsilon=0.0, device="cpu"):
        done_reward = None

        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            state_a = np.array([self.state], copy=False)
            state_v = torch.tensor(state_a).to(device)
            q_vals_v = net(state_v)
            _, act_v = torch.max(q_vals_v, dim=1)
            action = int(act_v.item())

        # do step in the environment
        new_state, reward, is_done, _ = self.env.step(action)
        self.total_reward += reward

        exp = Experience(self.state, action, reward, is_done, new_state)
        self.exp_buffer.append(exp)
        self.state = new_state
        if is_done:
            done_reward = self.total_reward
            self._reset()
        return done_reward

# %% [markdown]
# ## TD誤差の計算
# 強化学習は，TD誤差と呼ばれる次状態の推定の価値と実際に起こした行動から得られる価値の差を用いて学習を行います．次状態の推定の価値を教師あり学習の教師と同じ役割として計算します．DQNはQ学習をもとにしているため，現在の行動価値関数を最適行動価値関数になるように更新を行っていきます．
#
# TD誤差の計算を行う関数を定義します．calc_loss関数では，replay_bufferからランダムに取得したbatch分の経験をもとに下記のLoss計算を行います．
#
# \
# $$
# L_{\theta}=\frac{1}{2}(r+\gamma \max_{a'}Q_{\theta_{i}}(s',a')-Q_{\theta_{i}}(s,a))^{2}
# $$

# %%
def calc_loss(batch, net, tgt_net, device="cpu"):
    states, actions, rewards, dones, next_states = batch

    states_v = torch.tensor(states).to(device)
    next_states_v = torch.tensor(next_states).to(device)
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done_mask = torch.ByteTensor(dones).to(device)

    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    next_state_values = tgt_net(next_states_v).max(1)[0]
    next_state_values[done_mask] = 0.0
    next_state_values = next_state_values.detach()

    expected_state_action_values = next_state_values * GAMMA + rewards_v
    return nn.MSELoss()(state_action_values, expected_state_action_values)

# %% [markdown]
# ## 学習
# DQNを用いて学習を行います．学習環境はatari環境のPongゲーム環境を用います．各パラメータを定義します．Experience Replayで利用するReplay Bufferのサイズは1万とし，Replay Bufferが埋まるまでエージェントがランダムで動き，経験を貯めてから学習を行います．
#
# 学習回数を100万frame(num_frame)分とし，環境の終了条件はどちらかが21点とったら終了としています．また，最適化手法にはRMSprop利用します．
#
# 学習を開始します． まず，環境を初期化し，経験をReplayBufferへ蓄積します． 十分に蓄積された後，パラメータの更新を行います． また，SNC_TARGET_FRAMESで指定した回数ごとに，target_netのパラメータをnetのパラメータと同じになるようにコピーを行います．

# %%
MEAN_REWARD_BOUND = 19.5

GAMMA = 0.99
BATCH_SIZE = 32
REPLAY_SIZE = 10000
LEARNING_RATE = 1e-4
SYNC_TARGET_FRAMES = 1000
REPLAY_START_SIZE = 10000

EPSILON_DECAY_LAST_FRAME = 10**5
EPSILON_START = 1.0
EPSILON_FINAL = 0.02

num_frame = 1000000

device = 'cuda:0'

Experience = collections.namedtuple('Experience', field_names=['state', 'action', 'reward', 'done', 'new_state'])
net = DQN(env.observation_space.shape, env.action_space.n).to(device)
tgt_net = DQN(env.observation_space.shape, env.action_space.n).to(device)

buffer = ExperienceBuffer(REPLAY_SIZE)
agent = Agent(env, buffer)
epsilon = EPSILON_START

optimizer = optim.RMSprop(net.parameters(), lr=LEARNING_RATE)
total_rewards = []
frame_idx = 0
ts = time.time()
ts_frame = 0
best_mean_reward = None

while frame_idx < num_frame:
    frame_idx += 1
    epsilon = max(EPSILON_FINAL, EPSILON_START - frame_idx / EPSILON_DECAY_LAST_FRAME)

    reward = agent.play_step(net, epsilon, device=device)
    if reward is not None:
        total_rewards.append(reward)
        speed = (frame_idx - ts_frame) / (time.time() - ts)
        ts_frame = frame_idx
        ts = time.time()
        mean_reward = np.mean(total_rewards[-100:])
        print("%d: done %d games, mean reward %.3f, eps %.2f, speed %.2f f/s" % (
            frame_idx, len(total_rewards), mean_reward, epsilon,
            speed
        ))
        if best_mean_reward is None or best_mean_reward < mean_reward:
            torch.save(net.state_dict(), "Pong" + "-best.dat")
            if best_mean_reward is not None:
                print("Best mean reward updated %.3f -> %.3f, model saved" % (best_mean_reward, mean_reward))
            best_mean_reward = mean_reward
        if len(total_rewards) == 1000000:
            print("Solved in %d frames!" % frame_idx)
            break

    if len(buffer) < REPLAY_START_SIZE:
        continue

    if frame_idx % SYNC_TARGET_FRAMES == 0:
        sync_network()

    optimizer.zero_grad()
    batch = buffer.sample(BATCH_SIZE)
    loss_t = calc_loss(batch, net, tgt_net, device=device)
    loss_t.backward()
    optimizer.step()
# Out:
# 781: done 1 games, mean reward -21.000, eps 0.99, speed 506.78 f/s
# 1543: done 2 games, mean reward -21.000, eps 0.98, speed 545.25 f/s
# 2426: done 3 games, mean reward -20.667, eps 0.98, speed 561.96 f/s
# Best mean reward updated -21.000 -> -20.667, model saved
# 3246: done 4 games, mean reward -20.750, eps 0.97, speed 541.61 f/s
# 4057: done 5 games, mean reward -20.800, eps 0.96, speed 543.11 f/s
# 5096: done 6 games, mean reward -20.667, eps 0.95, speed 532.96 f/s
# 5948: done 7 games, mean reward -20.714, eps 0.94, speed 519.11 f/s
# 6848: done 8 games, mean reward -20.625, eps 0.93, speed 529.53 f/s
# Best mean reward updated -20.667 -> -20.625, model saved
# 7860: done 9 games, mean reward -20.444, eps 0.92, speed 528.48 f/s
# Best mean reward updated -20.625 -> -20.444, model saved
# 8756: done 10 games, mean reward -20.400, eps 0.91, speed 505.16 f/s
# Best mean reward updated -20.444 -> -20.400, model saved
# 9566: done 11 games, mean reward -20.455, eps 0.90, speed 512.08 f/s
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead. (Triggered internally at  /pytorch/aten/src/ATen/native/cuda/Indexing.cu:963.)
#   if sys.path[0] == '':
# 10356: done 12 games, mean reward -20.500, eps 0.90, speed 148.15 f/s
# 11118: done 13 games, mean reward -20.538, eps 0.89, speed 83.40 f/s
# 11954: done 14 games, mean reward -20.500, eps 0.88, speed 85.85 f/s
# 12772: done 15 games, mean reward -20.533, eps 0.87, speed 86.84 f/s
# 13622: done 16 games, mean reward -20.562, eps 0.86, speed 85.76 f/s
# 14521: done 17 games, mean reward -20.588, eps 0.85, speed 87.94 f/s
# 15362: done 18 games, mean reward -20.611, eps 0.85, speed 87.73 f/s
# 16202: done 19 games, mean reward -20.579, eps 0.84, speed 87.38 f/s
# 17137: done 20 games, mean reward -20.500, eps 0.83, speed 87.48 f/s
# 18219: done 21 games, mean reward -20.429, eps 0.82, speed 86.21 f/s
# 19028: done 22 games, mean reward -20.455, eps 0.81, speed 85.89 f/s
# 19864: done 23 games, mean reward -20.435, eps 0.80, speed 87.17 f/s
# 20774: done 24 games, mean reward -20.458, eps 0.79, speed 82.25 f/s
# 21536: done 25 games, mean reward -20.480, eps 0.78, speed 84.20 f/s
# 22606: done 26 games, mean reward -20.423, eps 0.77, speed 82.40 f/s
# 23428: done 27 games, mean reward -20.444, eps 0.77, speed 84.03 f/s
# 24278: done 28 games, mean reward -20.464, eps 0.76, speed 85.10 f/s
# 25179: done 29 games, mean reward -20.448, eps 0.75, speed 84.04 f/s
# 26016: done 30 games, mean reward -20.467, eps 0.74, speed 84.40 f/s
# 26923: done 31 games, mean reward -20.484, eps 0.73, speed 83.20 f/s
# 27811: done 32 games, mean reward -20.469, eps 0.72, speed 82.89 f/s
# 28737: done 33 games, mean reward -20.455, eps 0.71, speed 82.93 f/s
# 29622: done 34 games, mean reward -20.441, eps 0.70, speed 82.16 f/s
# 30608: done 35 games, mean reward -20.400, eps 0.69, speed 80.78 f/s
# 31389: done 36 games, mean reward -20.417, eps 0.69, speed 79.00 f/s
# 32170: done 37 games, mean reward -20.432, eps 0.68, speed 80.38 f/s
# 33100: done 38 games, mean reward -20.421, eps 0.67, speed 76.71 f/s
# 34342: done 39 games, mean reward -20.385, eps 0.66, speed 76.45 f/s
# Best mean reward updated -20.400 -> -20.385, model saved
# 35286: done 40 games, mean reward -20.400, eps 0.65, speed 77.38 f/s
# 36309: done 41 games, mean reward -20.415, eps 0.64, speed 78.99 f/s
# 37266: done 42 games, mean reward -20.405, eps 0.63, speed 79.40 f/s
# 38475: done 43 games, mean reward -20.349, eps 0.62, speed 79.16 f/s
# Best mean reward updated -20.385 -> -20.349, model saved
# 39603: done 44 games, mean reward -20.318, eps 0.60, speed 77.02 f/s
# Best mean reward updated -20.349 -> -20.318, model saved
# 40547: done 45 games, mean reward -20.333, eps 0.59, speed 74.79 f/s
# 41652: done 46 games, mean reward -20.326, eps 0.58, speed 76.14 f/s
# 42758: done 47 games, mean reward -20.277, eps 0.57, speed 77.56 f/s
# Best mean reward updated -20.318 -> -20.277, model saved
# 43714: done 48 games, mean reward -20.292, eps 0.56, speed 76.43 f/s
# 44933: done 49 games, mean reward -20.265, eps 0.55, speed 75.67 f/s
# Best mean reward updated -20.277 -> -20.265, model saved
# 46207: done 50 games, mean reward -20.220, eps 0.54, speed 73.68 f/s
# Best mean reward updated -20.265 -> -20.220, model saved
# 47310: done 51 games, mean reward -20.216, eps 0.53, speed 76.22 f/s
# Best mean reward updated -20.220 -> -20.216, model saved
# 48656: done 52 games, mean reward -20.173, eps 0.51, speed 75.23 f/s
# Best mean reward updated -20.216 -> -20.173, model saved
# 50393: done 53 games, mean reward -20.113, eps 0.50, speed 75.05 f/s
# Best mean reward updated -20.173 -> -20.113, model saved
# 51735: done 54 games, mean reward -20.111, eps 0.48, speed 72.04 f/s
# Best mean reward updated -20.113 -> -20.111, model saved
# 53458: done 55 games, mean reward -20.018, eps 0.47, speed 73.06 f/s
# Best mean reward updated -20.111 -> -20.018, model saved
# 55090: done 56 games, mean reward -19.982, eps 0.45, speed 73.12 f/s
# Best mean reward updated -20.018 -> -19.982, model saved
# 56420: done 57 games, mean reward -19.965, eps 0.44, speed 73.22 f/s
# Best mean reward updated -19.982 -> -19.965, model saved
# 57765: done 58 games, mean reward -19.931, eps 0.42, speed 71.92 f/s
# Best mean reward updated -19.965 -> -19.931, model saved
# 59159: done 59 games, mean reward -19.915, eps 0.41, speed 71.79 f/s
# Best mean reward updated -19.931 -> -19.915, model saved
# 60650: done 60 games, mean reward -19.867, eps 0.39, speed 72.82 f/s
# Best mean reward updated -19.915 -> -19.867, model saved
# 61854: done 61 games, mean reward -19.869, eps 0.38, speed 73.43 f/s
# 63584: done 62 games, mean reward -19.823, eps 0.36, speed 71.99 f/s
# Best mean reward updated -19.867 -> -19.823, model saved
# 64886: done 63 games, mean reward -19.778, eps 0.35, speed 71.22 f/s
# Best mean reward updated -19.823 -> -19.778, model saved
# 66447: done 64 games, mean reward -19.719, eps 0.34, speed 71.64 f/s
# Best mean reward updated -19.778 -> -19.719, model saved
# 67980: done 65 games, mean reward -19.692, eps 0.32, speed 71.75 f/s
# Best mean reward updated -19.719 -> -19.692, model saved
# 69805: done 66 games, mean reward -19.636, eps 0.30, speed 69.02 f/s
# Best mean reward updated -19.692 -> -19.636, model saved
# 72044: done 67 games, mean reward -19.507, eps 0.28, speed 67.61 f/s
# Best mean reward updated -19.636 -> -19.507, model saved
# 73908: done 68 games, mean reward -19.441, eps 0.26, speed 67.27 f/s
# Best mean reward updated -19.507 -> -19.441, model saved
# 75755: done 69 games, mean reward -19.377, eps 0.24, speed 66.49 f/s
# Best mean reward updated -19.441 -> -19.377, model saved
# 77251: done 70 games, mean reward -19.400, eps 0.23, speed 65.90 f/s
# 78844: done 71 games, mean reward -19.423, eps 0.21, speed 66.19 f/s
# 80986: done 72 games, mean reward -19.403, eps 0.19, speed 64.64 f/s
# 83143: done 73 games, mean reward -19.329, eps 0.17, speed 62.51 f/s
# Best mean reward updated -19.377 -> -19.329, model saved
# 85621: done 74 games, mean reward -19.270, eps 0.14, speed 61.24 f/s
# Best mean reward updated -19.329 -> -19.270, model saved
# 87590: done 75 games, mean reward -19.227, eps 0.12, speed 59.24 f/s
# Best mean reward updated -19.270 -> -19.227, model saved
# 90015: done 76 games, mean reward -19.145, eps 0.10, speed 57.70 f/s
# Best mean reward updated -19.227 -> -19.145, model saved
# 92449: done 77 games, mean reward -19.065, eps 0.08, speed 57.53 f/s
# Best mean reward updated -19.145 -> -19.065, model saved
# 95227: done 78 games, mean reward -18.974, eps 0.05, speed 56.32 f/s
# Best mean reward updated -19.065 -> -18.974, model saved
# 97978: done 79 games, mean reward -18.899, eps 0.02, speed 55.88 f/s
# Best mean reward updated -18.974 -> -18.899, model saved
# 100421: done 80 games, mean reward -18.837, eps 0.02, speed 55.40 f/s
# Best mean reward updated -18.899 -> -18.837, model saved
# 102823: done 81 games, mean reward -18.741, eps 0.02, speed 55.64 f/s
# Best mean reward updated -18.837 -> -18.741, model saved
# 106069: done 82 games, mean reward -18.622, eps 0.02, speed 55.72 f/s
# Best mean reward updated -18.741 -> -18.622, model saved
# 108880: done 83 games, mean reward -18.566, eps 0.02, speed 55.65 f/s
# Best mean reward updated -18.622 -> -18.566, model saved
# 111906: done 84 games, mean reward -18.488, eps 0.02, speed 55.99 f/s
# Best mean reward updated -18.566 -> -18.488, model saved
# 114846: done 85 games, mean reward -18.388, eps 0.02, speed 56.62 f/s
# Best mean reward updated -18.488 -> -18.388, model saved
# 117907: done 86 games, mean reward -18.302, eps 0.02, speed 56.69 f/s
# Best mean reward updated -18.388 -> -18.302, model saved
# 121444: done 87 games, mean reward -18.126, eps 0.02, speed 56.48 f/s
# Best mean reward updated -18.302 -> -18.126, model saved
# 124738: done 88 games, mean reward -18.034, eps 0.02, speed 56.50 f/s
# Best mean reward updated -18.126 -> -18.034, model saved
# 128337: done 89 games, mean reward -17.944, eps 0.02, speed 56.51 f/s
# Best mean reward updated -18.034 -> -17.944, model saved
# 131807: done 90 games, mean reward -17.844, eps 0.02, speed 56.31 f/s
# Best mean reward updated -17.944 -> -17.844, model saved
# 135282: done 91 games, mean reward -17.692, eps 0.02, speed 56.59 f/s
# Best mean reward updated -17.844 -> -17.692, model saved
# 138842: done 92 games, mean reward -17.435, eps 0.02, speed 56.51 f/s
# Best mean reward updated -17.692 -> -17.435, model saved
# 142567: done 93 games, mean reward -17.301, eps 0.02, speed 56.38 f/s
# Best mean reward updated -17.435 -> -17.301, model saved
# 146204: done 94 games, mean reward -17.096, eps 0.02, speed 56.48 f/s
# Best mean reward updated -17.301 -> -17.096, model saved
# 149296: done 95 games, mean reward -16.789, eps 0.02, speed 56.32 f/s
# Best mean reward updated -17.096 -> -16.789, model saved
# 152164: done 96 games, mean reward -16.521, eps 0.02, speed 56.46 f/s
# Best mean reward updated -16.789 -> -16.521, model saved
# 154458: done 97 games, mean reward -16.206, eps 0.02, speed 56.56 f/s
# Best mean reward updated -16.521 -> -16.206, model saved
# 156358: done 98 games, mean reward -15.857, eps 0.02, speed 56.52 f/s
# Best mean reward updated -16.206 -> -15.857, model saved
# 158172: done 99 games, mean reward -15.495, eps 0.02, speed 56.13 f/s
# Best mean reward updated -15.857 -> -15.495, model saved
# 160321: done 100 games, mean reward -15.190, eps 0.02, speed 56.11 f/s
# Best mean reward updated -15.495 -> -15.190, model saved
# 162494: done 101 games, mean reward -14.830, eps 0.02, speed 55.53 f/s
# Best mean reward updated -15.190 -> -14.830, model saved
# 164564: done 102 games, mean reward -14.460, eps 0.02, speed 56.16 f/s
# Best mean reward updated -14.830 -> -14.460, model saved
# 167018: done 103 games, mean reward -14.160, eps 0.02, speed 56.12 f/s
# Best mean reward updated -14.460 -> -14.160, model saved
# 168817: done 104 games, mean reward -13.760, eps 0.02, speed 56.63 f/s
# Best mean reward updated -14.160 -> -13.760, model saved
# 170448: done 105 games, mean reward -13.340, eps 0.02, speed 56.66 f/s
# Best mean reward updated -13.760 -> -13.340, model saved
# 173039: done 106 games, mean reward -13.000, eps 0.02, speed 56.70 f/s
# Best mean reward updated -13.340 -> -13.000, model saved
# 174993: done 107 games, mean reward -12.600, eps 0.02, speed 56.73 f/s
# Best mean reward updated -13.000 -> -12.600, model saved
# 176722: done 108 games, mean reward -12.200, eps 0.02, speed 56.41 f/s
# Best mean reward updated -12.600 -> -12.200, model saved
# 178909: done 109 games, mean reward -11.850, eps 0.02, speed 56.09 f/s
# Best mean reward updated -12.200 -> -11.850, model saved
# 181014: done 110 games, mean reward -11.480, eps 0.02, speed 55.95 f/s
# Best mean reward updated -11.850 -> -11.480, model saved
# 183456: done 111 games, mean reward -11.160, eps 0.02, speed 55.97 f/s
# Best mean reward updated -11.480 -> -11.160, model saved
# 185732: done 112 games, mean reward -10.800, eps 0.02, speed 56.56 f/s
# Best mean reward updated -11.160 -> -10.800, model saved
# 187723: done 113 games, mean reward -10.420, eps 0.02, speed 56.63 f/s
# Best mean reward updated -10.800 -> -10.420, model saved
# 189449: done 114 games, mean reward -10.020, eps 0.02, speed 55.78 f/s
# Best mean reward updated -10.420 -> -10.020, model saved
# 191854: done 115 games, mean reward -9.700, eps 0.02, speed 55.53 f/s
# Best mean reward updated -10.020 -> -9.700, model saved
# 193952: done 116 games, mean reward -9.340, eps 0.02, speed 56.45 f/s
# Best mean reward updated -9.700 -> -9.340, model saved
# 195682: done 117 games, mean reward -8.950, eps 0.02, speed 56.41 f/s
# Best mean reward updated -9.340 -> -8.950, model saved
# 197531: done 118 games, mean reward -8.560, eps 0.02, speed 56.09 f/s
# Best mean reward updated -8.950 -> -8.560, model saved
# 199538: done 119 games, mean reward -8.200, eps 0.02, speed 56.12 f/s
# Best mean reward updated -8.560 -> -8.200, model saved
# 201845: done 120 games, mean reward -7.850, eps 0.02, speed 54.91 f/s
# Best mean reward updated -8.200 -> -7.850, model saved
# 204481: done 121 games, mean reward -7.540, eps 0.02, speed 56.42 f/s
# Best mean reward updated -7.850 -> -7.540, model saved
# 207026: done 122 games, mean reward -7.210, eps 0.02, speed 55.97 f/s
# Best mean reward updated -7.540 -> -7.210, model saved
# 208859: done 123 games, mean reward -6.810, eps 0.02, speed 55.48 f/s
# Best mean reward updated -7.210 -> -6.810, model saved
# 210806: done 124 games, mean reward -6.420, eps 0.02, speed 55.78 f/s
# Best mean reward updated -6.810 -> -6.420, model saved
# 213190: done 125 games, mean reward -6.080, eps 0.02, speed 55.94 f/s
# Best mean reward updated -6.420 -> -6.080, model saved
# 215106: done 126 games, mean reward -5.720, eps 0.02, speed 55.48 f/s
# Best mean reward updated -6.080 -> -5.720, model saved
# 218193: done 127 games, mean reward -5.410, eps 0.02, speed 55.18 f/s
# Best mean reward updated -5.720 -> -5.410, model saved
# 220856: done 128 games, mean reward -5.060, eps 0.02, speed 53.80 f/s
# Best mean reward updated -5.410 -> -5.060, model saved
# 223065: done 129 games, mean reward -4.720, eps 0.02, speed 54.00 f/s
# Best mean reward updated -5.060 -> -4.720, model saved
# 225591: done 130 games, mean reward -4.350, eps 0.02, speed 54.36 f/s
# Best mean reward updated -4.720 -> -4.350, model saved
# 227554: done 131 games, mean reward -3.970, eps 0.02, speed 54.33 f/s
# Best mean reward updated -4.350 -> -3.970, model saved
# 230051: done 132 games, mean reward -3.640, eps 0.02, speed 54.22 f/s
# Best mean reward updated -3.970 -> -3.640, model saved
# 231822: done 133 games, mean reward -3.240, eps 0.02, speed 54.07 f/s
# Best mean reward updated -3.640 -> -3.240, model saved
# 233562: done 134 games, mean reward -2.840, eps 0.02, speed 53.88 f/s
# Best mean reward updated -3.240 -> -2.840, model saved
# 235456: done 135 games, mean reward -2.470, eps 0.02, speed 54.15 f/s
# Best mean reward updated -2.840 -> -2.470, model saved
# 237226: done 136 games, mean reward -2.070, eps 0.02, speed 54.46 f/s
# Best mean reward updated -2.470 -> -2.070, model saved
# 239203: done 137 games, mean reward -1.700, eps 0.02, speed 54.39 f/s
# Best mean reward updated -2.070 -> -1.700, model saved
# 241138: done 138 games, mean reward -1.330, eps 0.02, speed 54.13 f/s
# Best mean reward updated -1.700 -> -1.330, model saved
# 242861: done 139 games, mean reward -0.940, eps 0.02, speed 53.86 f/s
# Best mean reward updated -1.330 -> -0.940, model saved
# 244598: done 140 games, mean reward -0.530, eps 0.02, speed 54.24 f/s
# Best mean reward updated -0.940 -> -0.530, model saved
# 246657: done 141 games, mean reward -0.150, eps 0.02, speed 54.10 f/s
# Best mean reward updated -0.530 -> -0.150, model saved
# 248605: done 142 games, mean reward 0.230, eps 0.02, speed 54.02 f/s
# Best mean reward updated -0.150 -> 0.230, model saved
# 250491: done 143 games, mean reward 0.580, eps 0.02, speed 54.05 f/s
# Best mean reward updated 0.230 -> 0.580, model saved
# 252233: done 144 games, mean reward 0.970, eps 0.02, speed 54.32 f/s
# Best mean reward updated 0.580 -> 0.970, model saved
# 254498: done 145 games, mean reward 1.300, eps 0.02, speed 53.90 f/s
# Best mean reward updated 0.970 -> 1.300, model saved
# 256911: done 146 games, mean reward 1.600, eps 0.02, speed 54.62 f/s
# Best mean reward updated 1.300 -> 1.600, model saved
# 258621: done 147 games, mean reward 1.990, eps 0.02, speed 54.23 f/s
# Best mean reward updated 1.600 -> 1.990, model saved
# 260404: done 148 games, mean reward 2.400, eps 0.02, speed 54.18 f/s
# Best mean reward updated 1.990 -> 2.400, model saved
# 262247: done 149 games, mean reward 2.770, eps 0.02, speed 54.28 f/s
# Best mean reward updated 2.400 -> 2.770, model saved
# 264131: done 150 games, mean reward 3.120, eps 0.02, speed 54.41 f/s
# Best mean reward updated 2.770 -> 3.120, model saved
# 266085: done 151 games, mean reward 3.500, eps 0.02, speed 54.52 f/s
# Best mean reward updated 3.120 -> 3.500, model saved
# 267965: done 152 games, mean reward 3.860, eps 0.02, speed 54.39 f/s
# Best mean reward updated 3.500 -> 3.860, model saved
# 270186: done 153 games, mean reward 4.190, eps 0.02, speed 54.09 f/s
# Best mean reward updated 3.860 -> 4.190, model saved
# 271971: done 154 games, mean reward 4.590, eps 0.02, speed 54.15 f/s
# Best mean reward updated 4.190 -> 4.590, model saved
# 273897: done 155 games, mean reward 4.920, eps 0.02, speed 53.97 f/s
# Best mean reward updated 4.590 -> 4.920, model saved
# 275792: done 156 games, mean reward 5.280, eps 0.02, speed 54.33 f/s
# Best mean reward updated 4.920 -> 5.280, model saved
# 277573: done 157 games, mean reward 5.660, eps 0.02, speed 54.25 f/s
# Best mean reward updated 5.280 -> 5.660, model saved
# 279221: done 158 games, mean reward 6.050, eps 0.02, speed 54.05 f/s
# Best mean reward updated 5.660 -> 6.050, model saved
# 281316: done 159 games, mean reward 6.410, eps 0.02, speed 54.19 f/s
# Best mean reward updated 6.050 -> 6.410, model saved
# 283101: done 160 games, mean reward 6.770, eps 0.02, speed 53.81 f/s
# Best mean reward updated 6.410 -> 6.770, model saved
# 284792: done 161 games, mean reward 7.180, eps 0.02, speed 54.18 f/s
# Best mean reward updated 6.770 -> 7.180, model saved
# 286631: done 162 games, mean reward 7.540, eps 0.02, speed 54.44 f/s
# Best mean reward updated 7.180 -> 7.540, model saved
# 288499: done 163 games, mean reward 7.890, eps 0.02, speed 54.54 f/s
# Best mean reward updated 7.540 -> 7.890, model saved
# 290404: done 164 games, mean reward 8.230, eps 0.02, speed 54.47 f/s
# Best mean reward updated 7.890 -> 8.230, model saved
# 292122: done 165 games, mean reward 8.620, eps 0.02, speed 54.01 f/s
# Best mean reward updated 8.230 -> 8.620, model saved
# 293874: done 166 games, mean reward 8.980, eps 0.02, speed 54.45 f/s
# Best mean reward updated 8.620 -> 8.980, model saved
# 295885: done 167 games, mean reward 9.270, eps 0.02, speed 54.38 f/s
# Best mean reward updated 8.980 -> 9.270, model saved
# 297632: done 168 games, mean reward 9.620, eps 0.02, speed 54.35 f/s
# Best mean reward updated 9.270 -> 9.620, model saved
# 299628: done 169 games, mean reward 9.940, eps 0.02, speed 54.59 f/s
# Best mean reward updated 9.620 -> 9.940, model saved
# 301389: done 170 games, mean reward 10.330, eps 0.02, speed 54.40 f/s
# Best mean reward updated 9.940 -> 10.330, model saved
# 303300: done 171 games, mean reward 10.730, eps 0.02, speed 54.38 f/s
# Best mean reward updated 10.330 -> 10.730, model saved
# 305063: done 172 games, mean reward 11.110, eps 0.02, speed 53.97 f/s
# Best mean reward updated 10.730 -> 11.110, model saved
# 306843: done 173 games, mean reward 11.440, eps 0.02, speed 54.27 f/s
# Best mean reward updated 11.110 -> 11.440, model saved
# 308679: done 174 games, mean reward 11.790, eps 0.02, speed 54.12 f/s
# Best mean reward updated 11.440 -> 11.790, model saved
# 310343: done 175 games, mean reward 12.150, eps 0.02, speed 53.98 f/s
# Best mean reward updated 11.790 -> 12.150, model saved
# 312950: done 176 games, mean reward 12.390, eps 0.02, speed 53.91 f/s
# Best mean reward updated 12.150 -> 12.390, model saved
# 314836: done 177 games, mean reward 12.710, eps 0.02, speed 54.06 f/s
# Best mean reward updated 12.390 -> 12.710, model saved
# 316650: done 178 games, mean reward 13.030, eps 0.02, speed 54.20 f/s
# Best mean reward updated 12.710 -> 13.030, model saved
# 318831: done 179 games, mean reward 13.320, eps 0.02, speed 53.48 f/s
# Best mean reward updated 13.030 -> 13.320, model saved
# 320730: done 180 games, mean reward 13.640, eps 0.02, speed 54.20 f/s
# Best mean reward updated 13.320 -> 13.640, model saved
# 322702: done 181 games, mean reward 13.950, eps 0.02, speed 54.04 f/s
# Best mean reward updated 13.640 -> 13.950, model saved
# 324518: done 182 games, mean reward 14.240, eps 0.02, speed 54.27 f/s
# Best mean reward updated 13.950 -> 14.240, model saved
# 326209: done 183 games, mean reward 14.590, eps 0.02, speed 53.76 f/s
# Best mean reward updated 14.240 -> 14.590, model saved
# 328051: done 184 games, mean reward 14.910, eps 0.02, speed 53.88 f/s
# Best mean reward updated 14.590 -> 14.910, model saved
# 329852: done 185 games, mean reward 15.180, eps 0.02, speed 54.31 f/s
# Best mean reward updated 14.910 -> 15.180, model saved
# 331885: done 186 games, mean reward 15.470, eps 0.02, speed 54.26 f/s
# Best mean reward updated 15.180 -> 15.470, model saved
# 333580: done 187 games, mean reward 15.710, eps 0.02, speed 54.09 f/s
# Best mean reward updated 15.470 -> 15.710, model saved
# 335421: done 188 games, mean reward 16.000, eps 0.02, speed 55.46 f/s
# Best mean reward updated 15.710 -> 16.000, model saved
# 337330: done 189 games, mean reward 16.280, eps 0.02, speed 56.93 f/s
# Best mean reward updated 16.000 -> 16.280, model saved
# 338980: done 190 games, mean reward 16.580, eps 0.02, speed 57.16 f/s
# Best mean reward updated 16.280 -> 16.580, model saved
# 341160: done 191 games, mean reward 16.740, eps 0.02, speed 56.73 f/s
# Best mean reward updated 16.580 -> 16.740, model saved
# 342978: done 192 games, mean reward 16.860, eps 0.02, speed 56.65 f/s
# Best mean reward updated 16.740 -> 16.860, model saved
# 345431: done 193 games, mean reward 17.060, eps 0.02, speed 54.54 f/s
# Best mean reward updated 16.860 -> 17.060, model saved
# 347745: done 194 games, mean reward 17.200, eps 0.02, speed 53.38 f/s
# Best mean reward updated 17.060 -> 17.200, model saved
# 349633: done 195 games, mean reward 17.270, eps 0.02, speed 53.58 f/s
# Best mean reward updated 17.200 -> 17.270, model saved
# 351327: done 196 games, mean reward 17.380, eps 0.02, speed 53.65 f/s
# Best mean reward updated 17.270 -> 17.380, model saved
# 353202: done 197 games, mean reward 17.430, eps 0.02, speed 53.44 f/s
# Best mean reward updated 17.380 -> 17.430, model saved
# 354951: done 198 games, mean reward 17.450, eps 0.02, speed 53.56 f/s
# Best mean reward updated 17.430 -> 17.450, model saved
# 356736: done 199 games, mean reward 17.460, eps 0.02, speed 53.96 f/s
# Best mean reward updated 17.450 -> 17.460, model saved
# 358895: done 200 games, mean reward 17.470, eps 0.02, speed 53.74 f/s
# Best mean reward updated 17.460 -> 17.470, model saved
# 360953: done 201 games, mean reward 17.490, eps 0.02, speed 54.12 f/s
# Best mean reward updated 17.470 -> 17.490, model saved
# 362810: done 202 games, mean reward 17.510, eps 0.02, speed 53.86 f/s
# Best mean reward updated 17.490 -> 17.510, model saved
# 364505: done 203 games, mean reward 17.620, eps 0.02, speed 53.82 f/s
# Best mean reward updated 17.510 -> 17.620, model saved
# 366227: done 204 games, mean reward 17.630, eps 0.02, speed 53.93 f/s
# Best mean reward updated 17.620 -> 17.630, model saved
# 368178: done 205 games, mean reward 17.590, eps 0.02, speed 53.32 f/s
# 370021: done 206 games, mean reward 17.640, eps 0.02, speed 53.95 f/s
# Best mean reward updated 17.630 -> 17.640, model saved
# 371794: done 207 games, mean reward 17.660, eps 0.02, speed 53.32 f/s
# Best mean reward updated 17.640 -> 17.660, model saved
# 373921: done 208 games, mean reward 17.610, eps 0.02, speed 54.12 f/s
# 376189: done 209 games, mean reward 17.600, eps 0.02, speed 53.79 f/s
# 377885: done 210 games, mean reward 17.640, eps 0.02, speed 53.79 f/s
# 379693: done 211 games, mean reward 17.730, eps 0.02, speed 54.10 f/s
# Best mean reward updated 17.660 -> 17.730, model saved
# 381885: done 212 games, mean reward 17.750, eps 0.02, speed 53.85 f/s
# Best mean reward updated 17.730 -> 17.750, model saved
# 383692: done 213 games, mean reward 17.780, eps 0.02, speed 53.75 f/s
# Best mean reward updated 17.750 -> 17.780, model saved
# 385385: done 214 games, mean reward 17.790, eps 0.02, speed 53.58 f/s
# Best mean reward updated 17.780 -> 17.790, model saved
# 387038: done 215 games, mean reward 17.890, eps 0.02, speed 53.90 f/s
# Best mean reward updated 17.790 -> 17.890, model saved
# 388877: done 216 games, mean reward 17.930, eps 0.02, speed 53.70 f/s
# Best mean reward updated 17.890 -> 17.930, model saved
# 390571: done 217 games, mean reward 17.960, eps 0.02, speed 53.96 f/s
# Best mean reward updated 17.930 -> 17.960, model saved
# 392478: done 218 games, mean reward 17.970, eps 0.02, speed 53.81 f/s
# Best mean reward updated 17.960 -> 17.970, model saved
# 394773: done 219 games, mean reward 17.900, eps 0.02, speed 53.89 f/s
# 396695: done 220 games, mean reward 17.910, eps 0.02, speed 53.87 f/s
# 398406: done 221 games, mean reward 18.000, eps 0.02, speed 54.21 f/s
# Best mean reward updated 17.970 -> 18.000, model saved
# 400696: done 222 games, mean reward 17.970, eps 0.02, speed 56.54 f/s
# 402507: done 223 games, mean reward 17.960, eps 0.02, speed 56.12 f/s
# 404820: done 224 games, mean reward 17.930, eps 0.02, speed 56.49 f/s
# 406569: done 225 games, mean reward 18.000, eps 0.02, speed 56.23 f/s
# 408461: done 226 games, mean reward 18.030, eps 0.02, speed 56.41 f/s
# Best mean reward updated 18.000 -> 18.030, model saved
# 410158: done 227 games, mean reward 18.140, eps 0.02, speed 56.37 f/s
# Best mean reward updated 18.030 -> 18.140, model saved
# 411950: done 228 games, mean reward 18.190, eps 0.02, speed 56.01 f/s
# Best mean reward updated 18.140 -> 18.190, model saved
# 413754: done 229 games, mean reward 18.230, eps 0.02, speed 56.60 f/s
# Best mean reward updated 18.190 -> 18.230, model saved
# 415502: done 230 games, mean reward 18.270, eps 0.02, speed 56.29 f/s
# Best mean reward updated 18.230 -> 18.270, model saved
# 417198: done 231 games, mean reward 18.310, eps 0.02, speed 56.28 f/s
# Best mean reward updated 18.270 -> 18.310, model saved
# 419027: done 232 games, mean reward 18.370, eps 0.02, speed 56.43 f/s
# Best mean reward updated 18.310 -> 18.370, model saved
# 421331: done 233 games, mean reward 18.320, eps 0.02, speed 55.71 f/s
# 423112: done 234 games, mean reward 18.310, eps 0.02, speed 55.37 f/s
# 424981: done 235 games, mean reward 18.320, eps 0.02, speed 55.56 f/s
# 426709: done 236 games, mean reward 18.330, eps 0.02, speed 56.49 f/s
# 428949: done 237 games, mean reward 18.330, eps 0.02, speed 56.35 f/s
# 430908: done 238 games, mean reward 18.350, eps 0.02, speed 56.38 f/s
# 432804: done 239 games, mean reward 18.330, eps 0.02, speed 56.40 f/s
# 434808: done 240 games, mean reward 18.320, eps 0.02, speed 56.35 f/s
# 436461: done 241 games, mean reward 18.360, eps 0.02, speed 55.57 f/s
# 438207: done 242 games, mean reward 18.380, eps 0.02, speed 55.82 f/s
# Best mean reward updated 18.370 -> 18.380, model saved
# 440379: done 243 games, mean reward 18.340, eps 0.02, speed 56.28 f/s
# 442176: done 244 games, mean reward 18.320, eps 0.02, speed 56.30 f/s
# 443824: done 245 games, mean reward 18.410, eps 0.02, speed 56.08 f/s
# Best mean reward updated 18.380 -> 18.410, model saved
# 445592: done 246 games, mean reward 18.510, eps 0.02, speed 55.95 f/s
# Best mean reward updated 18.410 -> 18.510, model saved
# 447295: done 247 games, mean reward 18.500, eps 0.02, speed 56.12 f/s
# 449447: done 248 games, mean reward 18.470, eps 0.02, speed 55.97 f/s
# 451387: done 249 games, mean reward 18.490, eps 0.02, speed 55.51 f/s
# 453172: done 250 games, mean reward 18.500, eps 0.02, speed 56.36 f/s
# 455460: done 251 games, mean reward 18.470, eps 0.02, speed 56.20 f/s
# 457109: done 252 games, mean reward 18.500, eps 0.02, speed 55.78 f/s
# 458822: done 253 games, mean reward 18.550, eps 0.02, speed 55.42 f/s
# Best mean reward updated 18.510 -> 18.550, model saved
# 461633: done 254 games, mean reward 18.440, eps 0.02, speed 55.74 f/s
# 463459: done 255 games, mean reward 18.440, eps 0.02, speed 55.61 f/s
# 465676: done 256 games, mean reward 18.420, eps 0.02, speed 56.10 f/s
# 467457: done 257 games, mean reward 18.420, eps 0.02, speed 55.45 f/s
# 469503: done 258 games, mean reward 18.390, eps 0.02, speed 56.06 f/s
# 471417: done 259 games, mean reward 18.410, eps 0.02, speed 55.49 f/s
# 473356: done 260 games, mean reward 18.390, eps 0.02, speed 56.14 f/s
# 475104: done 261 games, mean reward 18.380, eps 0.02, speed 55.66 f/s
# 476791: done 262 games, mean reward 18.390, eps 0.02, speed 55.68 f/s
# 478602: done 263 games, mean reward 18.390, eps 0.02, speed 55.78 f/s
# 480393: done 264 games, mean reward 18.400, eps 0.02, speed 55.63 f/s
# 482044: done 265 games, mean reward 18.400, eps 0.02, speed 55.49 f/s
# 483776: done 266 games, mean reward 18.390, eps 0.02, speed 55.68 f/s
# 485425: done 267 games, mean reward 18.420, eps 0.02, speed 55.48 f/s
# 487299: done 268 games, mean reward 18.400, eps 0.02, speed 55.35 f/s
# 489203: done 269 games, mean reward 18.400, eps 0.02, speed 55.82 f/s
# 491011: done 270 games, mean reward 18.420, eps 0.02, speed 55.58 f/s
# 492663: done 271 games, mean reward 18.440, eps 0.02, speed 55.20 f/s
# 494379: done 272 games, mean reward 18.440, eps 0.02, speed 55.37 f/s
# 496094: done 273 games, mean reward 18.450, eps 0.02, speed 55.58 f/s
# 497980: done 274 games, mean reward 18.440, eps 0.02, speed 55.75 f/s
# 499711: done 275 games, mean reward 18.440, eps 0.02, speed 56.17 f/s
# 501464: done 276 games, mean reward 18.540, eps 0.02, speed 55.88 f/s
# 503440: done 277 games, mean reward 18.510, eps 0.02, speed 55.96 f/s
# 505106: done 278 games, mean reward 18.510, eps 0.02, speed 55.60 f/s
# 506851: done 279 games, mean reward 18.550, eps 0.02, speed 56.22 f/s
# 509054: done 280 games, mean reward 18.530, eps 0.02, speed 55.98 f/s
# 510704: done 281 games, mean reward 18.540, eps 0.02, speed 55.83 f/s
# 512352: done 282 games, mean reward 18.550, eps 0.02, speed 56.36 f/s
# 514270: done 283 games, mean reward 18.520, eps 0.02, speed 55.66 f/s
# 516568: done 284 games, mean reward 18.470, eps 0.02, speed 55.67 f/s
# 518407: done 285 games, mean reward 18.480, eps 0.02, speed 55.58 f/s
# 520055: done 286 games, mean reward 18.510, eps 0.02, speed 55.89 f/s
# 521800: done 287 games, mean reward 18.500, eps 0.02, speed 55.55 f/s
# 523798: done 288 games, mean reward 18.480, eps 0.02, speed 55.71 f/s
# 525603: done 289 games, mean reward 18.500, eps 0.02, speed 55.37 f/s
# 527304: done 290 games, mean reward 18.490, eps 0.02, speed 56.00 f/s
# 529046: done 291 games, mean reward 18.570, eps 0.02, speed 55.64 f/s
# Best mean reward updated 18.550 -> 18.570, model saved
# 530712: done 292 games, mean reward 18.600, eps 0.02, speed 55.19 f/s
# Best mean reward updated 18.570 -> 18.600, model saved
# 532414: done 293 games, mean reward 18.650, eps 0.02, speed 55.96 f/s
# Best mean reward updated 18.600 -> 18.650, model saved
# 534378: done 294 games, mean reward 18.670, eps 0.02, speed 55.60 f/s
# Best mean reward updated 18.650 -> 18.670, model saved
# 536026: done 295 games, mean reward 18.690, eps 0.02, speed 55.99 f/s
# Best mean reward updated 18.670 -> 18.690, model saved
# 537739: done 296 games, mean reward 18.690, eps 0.02, speed 55.35 f/s
# 539406: done 297 games, mean reward 18.710, eps 0.02, speed 55.62 f/s
# Best mean reward updated 18.690 -> 18.710, model saved
# 541107: done 298 games, mean reward 18.710, eps 0.02, speed 55.90 f/s
# 542958: done 299 games, mean reward 18.700, eps 0.02, speed 55.59 f/s
# 544796: done 300 games, mean reward 18.730, eps 0.02, speed 55.67 f/s
# Best mean reward updated 18.710 -> 18.730, model saved
# 546789: done 301 games, mean reward 18.750, eps 0.02, speed 56.19 f/s
# Best mean reward updated 18.730 -> 18.750, model saved
# 549024: done 302 games, mean reward 18.730, eps 0.02, speed 55.83 f/s
# 550754: done 303 games, mean reward 18.720, eps 0.02, speed 56.01 f/s
# 552596: done 304 games, mean reward 18.710, eps 0.02, speed 56.01 f/s
# 554546: done 305 games, mean reward 18.690, eps 0.02, speed 55.91 f/s
# 556369: done 306 games, mean reward 18.690, eps 0.02, speed 55.96 f/s
# 558020: done 307 games, mean reward 18.690, eps 0.02, speed 55.64 f/s
# 559862: done 308 games, mean reward 18.730, eps 0.02, speed 55.95 f/s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-edbf8d56cca2> in <module>()
#      62
#      63     optimizer.zero_grad()
# ---> 64     batch = buffer.sample(BATCH_SIZE)
#      65     loss_t = calc_loss(batch, net, tgt_net, device=device)
#      66     loss_t.backward()
#
# KeyboardInterrupt:

# %% [markdown]
# ## 評価
# 学習したネットワーク（エージェント）を確認してみます．
#
# ここでは，framesに描画したフレームを順次格納します．

# %%
# 結果を描画するための設定
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
import os
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display._obj._screen)


frames = []
for i in range(3):
    state = env.reset()
    done = False
    t = 0
    
    while not done and t < 200:
        frames.append(env.render(mode='rgb_array'))
        state_a = np.array([state], copy=False)
        state_v = torch.tensor(state_a).to(device)
        q_vals_v = net(state_v)
        _, act_v = torch.max(q_vals_v, dim=1)
        action = int(act_v.item())
        new_state, reward, is_done, _ = env.step(action)
        state = new_state
        done = is_done
        t += 1

# %% [markdown]
# ## 描画
#
# maptlotlibを用いて，保存した動画フレームをアニメーションとして作成し，表示しています．

# %%
# 実行結果の表示
import matplotlib.pyplot as plt
import matplotlib.animation
from IPython.display import HTML

plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
patch = plt.imshow(frames[0])
plt.axis('off')
animate = lambda i: patch.set_data(frames[i])
ani = matplotlib.animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval = 50)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img933fce8360664bd4a3d9c02f53857789">
#   <div class="anim-controls">
#     <input id="_anim_slider933fce8360664bd4a3d9c02f53857789" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim933fce8360664bd4a3d9c02f53857789.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim933fce8360664bd4a3d9c02f53857789.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select933fce8360664bd4a3d9c02f53857789" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_933fce8360664bd4a3d9c02f53857789"
#              >
#       <label for="_anim_radio1_933fce8360664bd4a3d9c02f53857789">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_933fce8360664bd4a3d9c02f53857789"
#              checked>
#       <label for="_anim_radio2_933fce8360664bd4a3d9c02f53857789">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_933fce8360664bd4a3d9c02f53857789"
#              >
#       <label for="_anim_radio3_933fce8360664bd4a3d9c02f53857789">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img933fce8360664bd4a3d9c02f53857789";
#     var slider_id = "_anim_slider933fce8360664bd4a3d9c02f53857789";
#     var loop_select_id = "_anim_loop_select933fce8360664bd4a3d9c02f53857789";
#     var frames = new Array(600);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4yLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+WH4yJAAAEUUlEQVR4nO3dO28cVRjH4XfWG8eXTZyLpYQygEQw\
# SClIkcIdFdR0qZHo8lkoqSMKPgEVVZAQEoICFCMEoqKIbIhxsB3fdiigQIq0kNiz/2X3eeqjd46s\
# n+bs7Eqepm3btiCkl94As02ARAmQKAESJUCiBEiUAIkSIFECJEqARAmQKAESJUCiBEiUAIkSIFEC\
# JEqARAmQKAESJUCiBEiUAIkSIFH9rga/fPnZ0U3T1Ae3BzU/15zptQZLSzU3Nzdyze7eXh2fnJzp\
# dVOO5/v1dPXCyDW9o5Na2tzpdB/3Pv3t1DM6C/DenYtdjX7G2quv1MpgMHLN1w836tft7THtqFt7\
# 11fqh/fujFyzuLlTb9x/MKYdvThHMFGd3QFTdvf36+Tvo3ZpYbH6/dFH8/9d7/C4Fh7/UVVVw36/\
# nl4dfRJMmqkL8OGPP9X2kydVV
